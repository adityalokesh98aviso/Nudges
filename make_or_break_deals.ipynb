# %%
body_template="""
<!-- Hygiene -->
<!DOCTYPE html>
<html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:o="urn:schemas-microsoft-com:office:office">
  <head>
    <script src="https://kit.fontawesome.com/13244967da.js"></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
    <meta charset="utf-8"> <!-- utf-8 works for most cases -->
    <meta name="viewport" content="width=device-width"> <!-- Forcing initial-scale shouldn't be necessary -->
    <meta http-equiv="X-UA-Compatible" content="IE=edge"> <!-- Use the latest (edge) version of IE rendering engine -->
    <meta name="x-apple-disable-message-reformatting">  <!-- Disable auto-scale in iOS 10 Mail entirely -->
    <meta name="format-detection" content="telephone=no,address=no,email=no,date=no,url=no"> <!-- Tell iOS not to automatically link certain text strings. -->
    <title></title> <!-- The title tag shows in email notifications, like Android 4.4. -->

    <!-- Web Font / @font-face : BEGIN -->
    <!-- NOTE: If web fonts are not required, lines 10 - 27 can be safely removed. -->

    <!-- Desktop Outlook chokes on web font references and defaults to Times New Roman, so we force a safe fallback font. -->
    <!--[if mso]>
      <style>
      * {
      font-family: "Open Sans", sans-serif !important;
      }
      </style>
    <![endif]-->

    <!-- CSS Reset : BEGIN -->
    <style>

     /* What it does: Remove spaces around the email design added by some email clients. */
     /* Beware: It can remove the padding / margin and add a background color to the compose a reply window. */
     html,
     body {
         margin: 0 !important;
         padding: 0 !important;
         height: 100% !important;
         width: 100% !important;
     }

     /* What it does: Stops email clients resizing small text. */
     * {
         -ms-text-size-adjust: 100%;
         -webkit-text-size-adjust: 100%;
     }

     /* What it does: Centers email on Android 4.4 */
     div[style*="margin: 16px 0"] {
         margin: 0 !important;
     }

     /* What it does: Stops Outlook from adding extra spacing to tables. */
     table,
     td {
         mso-table-lspace: 0pt !important;
         mso-table-rspace: 0pt !important;
     }

     /* What it does: Fixes webkit padding issue. */
     table {
         border-spacing: 0 !important;
         border-collapse: collapse !important;
         table-layout: fixed !important;
         margin: 0 auto !important;
     }

     /* What it does: Uses a better rendering method when resizing images in IE. */
     img {
         -ms-interpolation-mode:bicubic;
     }

     /* What it does: Prevents Windows 10 Mail from underlining links despite inline CSS. Styles for underlined links should be inline. */
     a {
         text-decoration: none;
     }

     /* What it does: A work-around for email clients meddling in triggered links. */
     a[x-apple-data-detectors],  /* iOS */
     .unstyle-auto-detected-links a,
     .aBn {
         border-bottom: 0 !important;
         cursor: default !important;
         color: inherit !important;
         text-decoration: none !important;
         font-size: inherit !important;
         font-family: inherit !important;
         font-weight: inherit !important;
         line-height: inherit !important;
     }

     /* What it does: Prevents Gmail from displaying a download button on large, non-linked images. */
     .a6S {
         display: none !important;
         opacity: 0.01 !important;
     }

     /* What it does: Prevents Gmail from changing the text color in conversation threads. */
     .im {
         color: inherit !important;
     }

     /* If the above doesn't work, add a .g-img class to any image in question. */
     img.g-img + div {
         display: none !important;
     }

     /* iPhone 4, 4S, 5, 5S, 5C, and 5SE */
     @media only screen and (min-device-width: 320px) and (max-device-width: 374px) {
         u ~ div .email-container {
             min-width: 320px !important;
         }

         .body-wrapper {
             padding: 1%;
         }

         .apple {
             margin: 10px 15px !important;
         }
     }
     /* iPhone 6, 6S, 7, 8, and X */
     @media only screen and (min-device-width: 375px) and (max-device-width: 413px) {
         u ~ div .email-container {
             min-width: 375px !important;
         }

         .body-wrapper {
             padding: 1%;
         }

         .apple {
             margin: 10px 25px !important;
         }
     }
     /* iPhone 6+, 7+, and 8+ */
     @media only screen and (min-device-width: 414px) {
         u ~ div .email-container {
             min-width: 414px !important;
         }

         .apple {
             margin: 10px 25px !important;
         }
     }

    </style>

    <!-- What it does: Makes background images in 72ppi Outlook render at correct size. -->
    <!--[if gte mso 9]>
      <xml>
      <o:OfficeDocumentSettings>
      <o:AllowPNG/>
      <o:PixelsPerInch>96</o:PixelsPerInch>
      </o:OfficeDocumentSettings>
      </xml>
    <![endif]-->

    <!-- Progressive Enhancements : BEGIN -->
    <style>

     /* Media Queries */
     @media screen and (max-width: 600px) {

         /* What it does: Adjust typography on small screens to improve readability */
         .email-container p {
             /*             font-size: 17px !important;*/
         }

     }

     /* custom css from here */

     body {
         font-family: "Open Sans", sans-serif;
     }

     .block_wrapper {
         border: 1px solid #d4d4d4;
         border-radius: 5px;
         margin: 10px 5% 10px;
         padding-bottom: 15px;
     }

     .store-logo {
         margin: 10px;
         display: inline-block;
     }

     .section-heading {
         color: #757575;
         font-size: 10px;
         padding: 5px;
     }

     .section-content {
         color: #424242;
         font-size: 14px;
         padding: 5px;
     }

     @media only screen and (width >= 768px) {

         .body-wrapper {
             padding: 6%;
         }

         .apple {
             margin: 10px 25px;
         }
     }


    </style>
    <!-- Progressive Enhancements : END -->

  </head>
  <!--
       The email background color (#222222) is defined in three places:
       1. body tag: for most email clients
       2. center tag: for Gmail and Inbox mobile apps and web versions of Gmail, GSuite, Inbox, Yahoo, AOL, Libero, Comcast, freenet, Mail.ru, Orange.fr
       3. mso conditional: For Windows 10 Mail
  -->
  <body width="100%" style="margin: 0; padding: 0 !important; mso-line-height-rule: exactly; background-color: #ffffff;">
    <center style="width: 100%; background-color: #ffffff;">
      <!--[if mso | IE]>
        <table role="presentation" border="0" cellpadding="0" cellspacing="0" width="100%" style="background-color: #ffffff;">
        <tr>
        <td>
      <![endif]-->

      <!--
           Set the email width. Defined in two places:
           1. max-width for all clients except Desktop Windows Outlook, allowing the email to squish on narrow but never go wider than 600px.
           2. MSO tags for Desktop Windows Outlook enforce a 600px width.
      -->
      <div style="max-width: 560px; min-width: 375px; margin: 0 auto; background-color: #F0F2F7;" class="email-container">
        <!--[if mso]>
          <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="600">
          <tr>
          <td>
        <![endif]-->

        <!-- Email Header : BEGIN -->

        <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
          <tr style="background-color: #151B42;">
            <td style="padding: 20px 0; text-align: center">
              <table role="presentation" cellspacing="0" cellpadding="0" width="100%">
                <tr>
                  <td>
                    <div style="padding: 20px;">
                      <a href="https://aviso.com" rel="noreferrer" target="_blank">
                        <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/aviso_red.png" />
                      </a>
                    </div>
                  </td>
                  <td style="color: #ffffff;">
                    <span style="font-size: 20px !important; font-weight: bold; display: inline-block; margin-bottom: 5px; margin-left: 10px; vertical-align: bottom;">Make or Break Deals</span>
                    <span style="font-size: 20px !important; font-weight: bold; display: inline-block; margin-bottom: 5px; margin-left: 10px; vertical-align: bottom;font-weight:200;">{{date}}</span>
                  </td>
                </tr>
              </table>
            </td>
          </tr>
        </table>
        <!-- Email Header : END -->

        <!-- Email Body : BEGIN -->
        <div style="padding: 3% 5%;">
          <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
            <tbody style="background-color: #F0F2F7; border: 13px solid transparent;">
              <!-- Welcome user : BEGIN -->
              <tr>
                <td>
                  <div>
                    <h3 style="font-size: 20px;margin:0px;">Hi {{user_name}} <img src="https://aviso-email-images.s3.amazonaws.com/waving-hand_1f44b.png" style="position:relative;top:6px;height:27px;width:auto;">,</h3>
                    <p style="font-size: 16px;;margin-bottom:10px;color:black;font-weight:400;margin-top:10px;">Aviso Identified  {{make_deals|length + break_deals|length}} deals with high/low chance of closure that could help with your quota attainment: </p>
                  </div>
                </td>
              </tr>

              <!-- Welcome user : END -->

              <!-- Content block : BEGIN -->

             </tr>


             {% if  make_deals|length > 0 %}

              <tr>
                <td>



                    <div style="width:476px;height:auto;background:white;margin-top:5px;padding-bottom:25px;">

                      <div style="color:#404255;font-size:16px;font-weight:bold;text-align:center;padding-top:14px;">
                        High Chance of Closures
                      </div>
                      <div style="color:#6f7288;font-size:12px;font-weight:bold;text-align:center;font-weight:200;">
                        Make or break deals
                      </div>
                      <div style="background:#dff5ff;font-size:12px;font-weight:bold;text-align:center;font-weight:200;margin:auto;width:90%;padding:2%;text-align:left;margin-top:15px;">
                        <p style="color:#6f7288;">Aviso identified deals with high chance of closure  that could help with your quota attainment.
                      </div>
                      {% for deal in make_deals %}
                   <div style="width:476px;height:170px;border-radius:5px;background:white;margin-top:5px;margin-bottom:5px;">
                    <img src="https://aviso-email-images.s3.amazonaws.com/win_scores/{{deal.aviso_score|int}}.png" style="display: inline-flex;
                                width: 32px;
                                height: 32px;
                                margin: 16px 18px;
                                vertical-align: top;
                                ">
                <div style="display:inline-block;min-width:40%;max-width:70%;margin-bottom:15px;">
                  <p style="color:#0991cc;font-size:15px;margin-top:15px;margin-bottom:1px;font-weight:bold;word-break: break-all; word-wrap: break-word;">
                {{deal.deal_name}}
                  </p>
                  <p style="color:#6f7288;font-size:12px;font-weight:200;margin-top:0px;margin-bottom:3px;word-break: break-all; word-wrap: break-word;">
                    Owner: {{deal.deal_owner}}
                  </p>
                  <table align="center" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;display:inline-block">
                    <tr>
                    <td style="color:#6f7288;font-size: 13px;font-weight: 400;width:30%;word-break: break-all; word-wrap: break-word;vertical-align:top;">Amount: {{deal.amount}}</td>

                  </tr>
                    <tr>
                  <td style="color:#6f7288;font-size: 13px;font-weight: 400;width:35%;word-break: break-all; word-wrap: break-word;vertical-align:top;">Close Date: {{deal.close_date}}</td>
                  </tr>

                </table>




                </div>
                <table align="right" style="height:100%;">
                  <tr>

                      <td><a href="{{deal.update_deal_link}}"><img  src="https://aviso-email-images.s3.amazonaws.com/Chevron-Right.png" style="width:20px;height:20px;float:right;padding-right: 40%;"></img></a></td>
                  </tr>
                </table>


              </div>
              <div style="width: 85%; border-bottom: 1px solid #c7cbd6; margin: 0 auto;"></div>
              {%endfor%}

              <a href="{{make_deals_link}}" style="margin:auto;background:#3d4689;height:5px !important;width:20% !important; border: 1px solid #151B42; font-family: Open Sans Regular, sans-serif; font-size: 11pt;text-decoration: none; padding: 13px 17px; color: #ffffff; display: block;border-radius: 4px; text-align: center;line-height:5px;margin-top:25px;">View All  Deals

              </a>


            </div>

              </td>

              </tr>


              {% endif %}


              

               {% if  break_deals|length > 0 %}
              <tr>
                <tr>
                  <td>



                      <div style="width:476px;height:auto;background:white;margin-top:5px;padding-bottom:25px;margin-top:28px;">

                        <div style="color:#404255;font-size:16px;font-weight:bold;text-align:center;padding-top:14px;">
                          Low Chance of Closures
                        </div>
                        <div style="color:#6f7288;font-size:12px;font-weight:bold;text-align:center;font-weight:200;">
                          Make or break deals
                        </div>
                        <div style="background:#dff5ff;font-size:12px;font-weight:bold;text-align:center;font-weight:200;margin:auto;width:90%;padding:2%;text-align:left;margin-top:15px;">
                           <p style="color:#6f7288;">Aviso identified deals with low chance of closure  that could Impact with your quota attainment.
                        </div>
                        {% for deal in break_deals %}
                     <div style="width:476px;height:170px;border-radius:5px;background:white;margin-top:5px;margin-bottom:5px;">
                      <img src="https://aviso-email-images.s3.amazonaws.com/win_scores/{{deal.aviso_score|int}}.png" style="display: inline-flex;
                                  width: 32px;
                                  height: 32px;
                                  margin: 16px 18px;
                                  vertical-align: top;
                                  ">
                  <div style="display:inline-block;min-width:40%;max-width:70%;">
                    <p style="color:#0991cc;font-size:15px;margin-top:15px;margin-bottom:1px;font-weight:bold;word-break: break-all; word-wrap: break-word;">
                  {{deal.deal_name}}
                    </p>
                    <p style="color:#6f7288;font-size:12px;font-weight:200;margin-top:0px;margin-bottom:3px;word-break: break-all; word-wrap: break-word;">
                      Owner: {{deal.deal_owner}}
                    </p>
                    <table align="center" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;display:inline-block">
                      <tr>
                      <td style="color:#6f7288;font-size: 13px;font-weight: 400;width:30%;word-break: break-all; word-wrap: break-word;vertical-align:top;">Amount: {{deal.amount}}</td>

                    </tr>
                      <tr>
                    <td style="color:#6f7288;font-size: 13px;font-weight: 400;width:35%;word-break: break-all; word-wrap: break-word;vertical-align:top;">Close Date: {{deal.close_date}}</td>
                    </tr>

                  </table>
                  </div>
                  <table align="right" style="height:100%;">
                    <tr>

                        <td><a href="{{deal.update_deal_link}}"><img  src="https://aviso-email-images.s3.amazonaws.com/Chevron-Right.png" style="width:20px;height:20px;float:right;padding-right: 40%;"></img></a></td>

                    </tr>
                  </table>
                </div>
                <div style="width: 85%; border-bottom: 1px solid #c7cbd6; margin: 0 auto;"></div>
                  {%endfor%}
                  <a href="{{break_deals_link}}" style="margin:auto;background:#3d4689;height:5px !important;width:20% !important; border: 1px solid #151B42; font-family: Open Sans Regular, sans-serif; font-size: 11pt;text-decoration: none; padding: 13px 17px; color: #ffffff; display: block;border-radius: 4px; text-align: center;line-height:5px;margin-top:25px;">View All Deals

                  </a>
              </div>
                </td>

                </tr>

                  {% endif %}







                    <!-- <div style="width: 90%; border-bottom: 1px solid #757575; margin: 10px auto;"></div> -->
                    <!-- <div style="font-size: 14px; color: #404255; width: 84%; margin: 0 auto;">
                      <p style="color: #151B42;"><b>Deal Insights:</b></p>
                      <table role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
                        <tr>
                          <td style="width: 8%;">
                            <img src="https://aviso-email-images.s3.amazonaws.com/chevron-circle-up-solid 2.png" width="15.5px" height="15.5px" style="display: inline-block; margin-top: 2px;" />

                          </td>
                          <td>
                            <p style="margin-left: 5%;">This is an insight</p>
                              </td>
                            </tr>

                      </table>
                    </div> -->

              <!-- Content block : END -->
              <!-- Clear Spacer : BEGIN -->

              <!-- Clear Spacer : END -->

              <!-- 1 Column Text : BEGIN -->

              <tr>
                <td>
                  <p style="color: #404255; font-size: 14px; line-height: 20.9px; text-align: center; max-width: 360px;width:251px; margin: 0 auto;margin-top:40px;">Keep up-to-date with you deals on iPhone or Android with Aviso Go.</p>
                </td>
              </tr>
              <tr>
                <td style="background-color: #f0f2f7;">
                  <div style="max-width: 360px; margin: 0 auto;">
                    <a href="https://apps.apple.com/us/app/avisogo/id1250216779" style="margin: 0px 7%;">
                      <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/Apple-AppStore_download.png" style="40px;"/>
                    </a>
                    <a href="https://play.google.com/store/apps/details?id=com.aviso.avisogo"
                       style="margin: 10px;
                             display: inline-block;
                             ">
                      <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/Android-AppStore_download.png" />
                    </a>
                  </div>
                <a href="mailto:support@aviso.com?subject=Feedback%20on%20{{nudge_name}}"><p align="center" style="font-size:13px;color:#757575;font-weight:200;">Is this email useful?  We love <span style="color:#1f9ef4;"><u>feedback!</u></span></p><a/>

                </td>
              </tr>
              <!-- 1 Column Text : END -->
            </tbody>
          </table>
        </div>
        <!-- Email Body : END -->

        <!-- Email Footer : BEGIN -->
        <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
          <tr>
            <td>
            <div style="width: 85%; border-bottom: 1px solid #c7cbd6; margin: 0 auto;"></div>
            </td>
          </tr>

          <tr>
            <td>
              <div style="width: 88%; margin: 0 auto;">
                <table role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%">
                  <tr>
                    <td style="width: 15%; padding: 5%;">
                      <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/logo_footer_red.png" />
                    </td>
                    <td style="text-align:right;">
                        <p><a href="mailto:support@aviso.com?subject=Unscubscribe%20{{nudge_name}}" style="color: #757575; font-size: 10px;text-align:right;font-weight:200;"><u>Unscubscribe  from these emails</u></a></p>
                      <p style="color: #757575; font-size: 12px; line-height: 17.9px; text-align: right;">Copyright &copy; 2020 Aviso Inc. All rights reserved.</p>
                  </td>
                </tr>
              </table>
            </div>
          </td>
        </tr>
      </table>
      <!-- Email Footer : END -->

      <!--[if mso]>
        </td>
        </tr>
        </table>
      <![endif]-->
      </div>

      <!--[if mso | IE]>
        </td>
        </tr>
        </table>
      <![endif]-->
      <img src="{{opens_tracker}}" style="width: 1px; height: 1px">
    </center>
  </body>
</html>  
"""
subject_template ='{{(tenant_name~" -- "~nudge_name~" - " if test_mode==True else "")~" '+ 'Your make or break deals for the quarter' +'"}}'
is_html = True
name = "make_or_break_deals"
optional = [""]

# %%
noti.api('/notify/api/email_template/', {"name": name,"subject_template":subject_template, "body_template": body_template,
                                     "is_html": is_html, 'optional':optional, 'action': "update"} )
# Out:
# {u'message': u'Template added successfully', u'success': True}

# %%
noti.api('/notify/api/notification/', {'action':'create', 
                                       'name' : 'make_or_break_deals', 
                                       'template_name':{'email': 'make_or_break_deals'}, 
                                       'template_data':{
                                        "email": ['date', 'user_name','make_deals','break_deals', 'test_mode','tenant_name','nudge_name', 'make_deals_link', 'break_deals_link', 'opens_tracker']
                                        },
                                    "track_urls":[]
                                      })
# Out:
# {u'action': u'create', u'success': True}

# %%
import avisosdk
noti = avisosdk.connect_sdk("https://notification-qa.aviso.com")
noti.login(username='aditya@administrative.domain')
# Out:
# [PID] 2021-Jan-19 16:14:17 - INFO - Starting new HTTPS connection (1): notification-qa.aviso.com
# [PID] 2021-Jan-19 16:14:18 - INFO - No logged in session. Login first
# password?········
# Connected to url: https://notification-qa.aviso.com tenant: administrative.domain

# %%
event_name ='make_or_break_deals'
payload ={
    'date':'11pm 23rd jun 2020',
    'test_mode':True,
    'tenant_name':'aditya',
    'nudge_name':'high amount',
    "user_name":"Final Nudge",
    "make_deals":[ 
       ],
    "break_deals":[{
            "aviso_score":11,
            
            "deal_name":"Nike License Contract 500 deals Nike License Contract 500 deals the deal names are enlarged to make the sentence longer than usually. ",
            "deal_owner":"Nike incorporated",
            "amount":"$24,345,23",
            "close_date":"25th Jan 2020",
            "no_of_change":4,
            "update_deal_link":"abc.com",
            
        },
             {
            "aviso_score":71,
            "deal_name":"Velo deal signoff 600 deals Nike License Contract 500 deals the deal names are enlarged to make the sentence longer than usually.new License working nudge Nike License Cont",
            "deal_owner":"Velo Licenses ",
            "amount":"$12,234,67",
            "close_date":"30 march 2020",
            "no_of_change":4,
            "update_deal_link":"abc.com",
            
        },
             {
            "aviso_score":66,
            "deal_name":"the deal names are enlarged to make the sentence longer than usually.new License working nudge Nike License Contract 500 deals the deal names are enlarged to make the sentence longer than usually.",
            "deal_owner":"navita singh",
            "amount":"$125,324,33",
            "close_date":"28th Feb 2020",
            "no_of_change":4,
            "update_deal_link":"abc.com",
            
        },
                    {
            "aviso_score":44,
            "deal_name":"to make the sentence longer than usually.new License working nudge Nike License Contract 500 deals the deal names are enlarged to make the sentence longer than usually.",
            "deal_owner":"navita singh",
            "amount":"$125,324,33",
            "close_date":"28th Feb 2020",
            "no_of_change":4,
            "update_deal_link":"abc.com",
            
        },
            
       ],
"break_deals_link":"https://www.abc.com",
"make_deals_link":"https://www.abc.com",
"filtered_deals":'https:www.abc.com',
"opens_tracker":"abc.com",
"recipients": "aditya.lokesh@aviso.com",
"skip_header_footer": True,
    }
noti.api('/notify/api/test_notification', {'event_name': event_name, 'payload': payload})
# Out:
# {u'message': u'Event Published successfully', u'success': True}
