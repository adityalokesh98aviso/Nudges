# %%
import avisosdk
noti = avisosdk.connect_sdk("https://notification-qa.aviso.com")
noti.login(username='aditya@administrative.domain')
# Out:
# 2021-May-03 13:20:14 - INFO - Starting new HTTPS connection (1): notification-qa.aviso.com
# 2021-May-03 13:20:16 - INFO - Starting new HTTPS connection (1): notification-qa.aviso.com
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-53d913ec7ae9> in <module>()
#       1 import avisosdk
# ----> 2 noti = avisosdk.connect_sdk("https://notification-qa.aviso.com")
#       3 noti.login(username='aditya@administrative.domain')
#
# /Users/adityalokesh/venp/src/aviso-sdk/avisosdk/__init__.pyc in connect_sdk(url, sdk_path, tracer)
#    1596         try:
#    1597             connection = SDKConnection(url, sdk_path, use_different_name)
# -> 1598             connection.setup(tracer=tracer)
#    1599             return connection.shell
#    1600         except (ZipError, EOFError, EnvironmentError) as e:
#
# /Users/adityalokesh/venp/src/aviso-sdk/avisosdk/__init__.pyc in setup(self, tracer)
#    1579     def setup(self, tracer):
#    1580         if not self.sdk_path or self.use_different_name:
# -> 1581             sdk_gzip = self._fetch_sdk_package()
#    1582         else:
#    1583             self.version = NOT_DEFINED
#
# /Users/adityalokesh/venp/src/aviso-sdk/avisosdk/__init__.pyc in _fetch_sdk_package(self)
#    1517                     already_exists = True
#    1518                 else:
# -> 1519                     response = requests.get(url, stream=True)
#    1520                 if self.use_different_name :
#    1521                     filename = self.version + "_" + str(uuid.uuid4()) + ".zip"
#
# /Users/adityalokesh/venp/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      67
#      68     kwargs.setdefault('allow_redirects', True)
# ---> 69     return request('get', url, params=params, **kwargs)
#      70
#      71
#
# /Users/adityalokesh/venp/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      48
#      49     session = sessions.Session()
# ---> 50     response = session.request(method=method, url=url, **kwargs)
#      51     # By explicitly closing the session, we avoid leaving sockets open which
#      52     # can trigger a ResourceWarning in some cases, and look like a memory leak
#
# /Users/adityalokesh/venp/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     463         }
#     464         send_kwargs.update(settings)
# --> 465         resp = self.send(prep, **send_kwargs)
#     466
#     467         return resp
#
# /Users/adityalokesh/venp/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     571
#     572         # Send the request
# --> 573         r = adapter.send(request, **kwargs)
#     574
#     575         # Total elapsed time of the request (approximately)
#
# /Users/adityalokesh/venp/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     368                     decode_content=False,
#     369                     retries=self.max_retries,
# --> 370                     timeout=timeout
#     371                 )
#     372
#
# /Users/adityalokesh/venp/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     542             httplib_response = self._make_request(conn, method, url,
#     543                                                   timeout=timeout_obj,
# --> 544                                                   body=body, headers=headers)
#     545
#     546             # If we're going to release the connection in ``finally:``, then
#
# /Users/adityalokesh/venp/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     370         try:
#     371             try:  # Python 2.7, use buffering of HTTP responses
# --> 372                 httplib_response = conn.getresponse(buffering=True)
#     373             except TypeError:  # Python 2.6 and older
#     374                 httplib_response = conn.getresponse()
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     752                     "non-zero flags not allowed in calls to recv() on %s" %
#     753                     self.__class__)
# --> 754             return self.read(buflen)
#     755         else:
#     756             return self._sock.recv(buflen, flags)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     639                 v = self._sslobj.read(len, buffer)
#     640             else:
# --> 641                 v = self._sslobj.read(len)
#     642             return v
#     643         except SSLError as x:
#
# KeyboardInterrupt:

# %%
body_template="""
<!-- Hygiene -->
<!DOCTYPE html>
<html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:o="urn:schemas-microsoft-com:office:office">
  <head>
    <script src="https://kit.fontawesome.com/13244967da.js"></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
    <meta charset="utf-8"> <!-- utf-8 works for most cases -->
    <meta name="viewport" content="width=device-width"> <!-- Forcing initial-scale shouldn't be necessary -->
    <meta http-equiv="X-UA-Compatible" content="IE=edge"> <!-- Use the latest (edge) version of IE rendering engine -->
    <meta name="x-apple-disable-message-reformatting">  <!-- Disable auto-scale in iOS 10 Mail entirely -->
    <meta name="format-detection" content="telephone=no,address=no,email=no,date=no,url=no"> <!-- Tell iOS not to automatically link certain text strings. -->
    <title></title> <!-- The title tag shows in email notifications, like Android 4.4. -->

    <!-- Web Font / @font-face : BEGIN -->
    <!-- NOTE: If web fonts are not required, lines 10 - 27 can be safely removed. -->

    <!-- Desktop Outlook chokes on web font references and defaults to Times New Roman, so we force a safe fallback font. -->
    <!--[if mso]>
      <style>
      * {
      font-family: "Open Sans", sans-serif !important;
      }
      </style>
    <![endif]-->

    <!-- CSS Reset : BEGIN -->
    <style>


     /* What it does: Remove spaces around the email design added by some email clients. */
     /* Beware: It can remove the padding / margin and add a background color to the compose a reply window. */
     html,
     body {
         margin: 0 !important;
         padding: 0 !important;
         height: 100% !important;
         width: 100% !important;
     }

     /* What it does: Stops email clients resizing small text. */
     * {
         -ms-text-size-adjust: 100%;
         -webkit-text-size-adjust: 100%;
     }

     /* What it does: Centers email on Android 4.4 */
     div[style*="margin: 16px 0"] {
         margin: 0 !important;
     }


     /* What it does: Stops Outlook from adding extra spacing to tables. */
     table,
     td {
         mso-table-lspace: 0pt !important;
         mso-table-rspace: 0pt !important;
     }

     /* What it does: Fixes webkit padding issue. */
     table {
         border-spacing: 0 !important;
         border-collapse: collapse !important;
         table-layout: fixed !important;
         margin: 0 auto !important;
     }

     /* What it does: Uses a better rendering method when resizing images in IE. */
     img {
         -ms-interpolation-mode:bicubic;
     }

     /* What it does: Prevents Windows 10 Mail from underlining links despite inline CSS. Styles for underlined links should be inline. */
     a {
         text-decoration: none;
     }

     /* What it does: A work-around for email clients meddling in triggered links. */
     a[x-apple-data-detectors],  /* iOS */
     .unstyle-auto-detected-links a,
     .aBn {
         border-bottom: 0 !important;
         cursor: default !important;
         color: inherit !important;
         text-decoration: none !important;
         font-size: inherit !important;
         font-family: inherit !important;
         font-weight: inherit !important;
         line-height: inherit !important;
     }

     /* What it does: Prevents Gmail from displaying a download button on large, non-linked images. */
     .a6S {
         display: none !important;
         opacity: 0.01 !important;
     }

     /* What it does: Prevents Gmail from changing the text color in conversation threads. */
     .im {
         color: inherit !important;
     }

     /* If the above doesn't work, add a .g-img class to any image in question. */
     img.g-img + div {
         display: none !important;
     }

     /* iPhone 4, 4S, 5, 5S, 5C, and 5SE */
     @media only screen and (min-device-width: 320px) and (max-device-width: 374px) {
         u ~ div .email-container {
             min-width: 320px !important;
         }

         .body-wrapper {
             padding: 1%;
         }

         .apple {
             margin: 10px 15px !important;
         }
     }
     /* iPhone 6, 6S, 7, 8, and X */
     @media only screen and (min-device-width: 375px) and (max-device-width: 413px) {
         u ~ div .email-container {
             min-width: 375px !important;
         }

         .body-wrapper {
             padding: 1%;
         }

         .apple {
             margin: 10px 25px !important;
         }
     }
     /* iPhone 6+, 7+, and 8+ */
     @media only screen and (min-device-width: 414px) {
         u ~ div .email-container {
             min-width: 414px !important;
         }

         .apple {
             margin: 10px 25px !important;
         }
     }

    </style>

    <!-- What it does: Makes background images in 72ppi Outlook render at correct size. -->
    <!--[if gte mso 9]>
      <xml>
      <o:OfficeDocumentSettings>
      <o:AllowPNG/>
      <o:PixelsPerInch>96</o:PixelsPerInch>
      </o:OfficeDocumentSettings>
      </xml>
    <![endif]-->

    <!-- Progressive Enhancements : BEGIN -->
    <style>

     /* Media Queries */
     @media screen and (max-width: 600px) {

         /* What it does: Adjust typography on small screens to improve readability */
         .email-container p {
             /*             font-size: 17px !important;*/
         }

     }

     /* custom css from here */

     body {
         font-family: "Open Sans", sans-serif;
     }

     .block_wrapper {
         border: 1px solid #d4d4d4;
         border-radius: 5px;
         margin: 10px 5% 10px;
         padding-bottom: 15px;
     }

     .store-logo {
         margin: 10px;
         display: inline-block;
     }

     .section-heading {
         color: #757575;
         font-size: 10px;
         padding: 5px;
     }

     .section-content {
         color: #424242;
         font-size: 14px;
         padding: 5px;
     }

     @media only screen and (width >= 768px) {

         .body-wrapper {
             padding: 6%;
         }

         .apple {
             margin: 10px 25px;
         }
     }


    </style>
    <!-- Progressive Enhancements : END -->

  </head>
  <!--
       The email background color (#222222) is defined in three places:
       1. body tag: for most email clients
       2. center tag: for Gmail and Inbox mobile apps and web versions of Gmail, GSuite, Inbox, Yahoo, AOL, Libero, Comcast, freenet, Mail.ru, Orange.fr
       3. mso conditional: For Windows 10 Mail
  -->
  <body width="100%" style="margin: 0; padding: 0 !important; mso-line-height-rule: exactly; background-color: #ffffff;">
    <center style="width: 100%; background-color: #ffffff;">
      <!--[if mso | IE]>
        <table role="presentation" border="0" cellpadding="0" cellspacing="0" width="100%" style="background-color: #ffffff;">
        <tr>
        <td>
      <![endif]-->

      <!--
           Set the email width. Defined in two places:
           1. max-width for all clients except Desktop Windows Outlook, allowing the email to squish on narrow but never go wider than 600px.
           2. MSO tags for Desktop Windows Outlook enforce a 600px width.
      -->
      <div style="max-width: 560px; min-width: 375px; margin: 0 auto; background-color: #F0F2F7;" class="email-container">
        <!--[if mso]>
          <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="600">
          <tr>
          <td>
        <![endif]-->

        <!-- Email Header : BEGIN -->

        <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
          <tr style="background-color: #151B42;">
            <td style="padding: 20px 0; text-align: center">
              <table role="presentation" cellspacing="0" cellpadding="0" width="100%">
                <tr>
                  <td>
                    <div style="padding: 20px;">
                      <a href="https://aviso.com" rel="noreferrer" target="_blank">
                        <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/aviso_red.png" />
                      </a>
                    </div>
                  </td>
                  <td style="color: #ffffff;width:60%;">
                    <span style="font-size: 20px !important; font-weight: bold; display: inline-block; margin-bottom: 5px; margin-left: 10px; vertical-align: bottom;position:relative;right:4px;">Product Recommendation</span>
                    <span style="font-size: 20px !important; font-weight: bold; display: inline-block; margin-bottom: 5px; margin-left: 10px; vertical-align: bottom;font-weight:200;">{{date}}</span>
                  </td>
                </tr>
              </table>
            </td>
          </tr>
        </table>
        <!-- Email Header : END -->

        <!-- Email Body : BEGIN -->
        <div style="padding: 3% 2%;">
          <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
            <tbody style="background-color: #F0F2F7; border: 13px solid transparent;">
              <!-- Welcome user : BEGIN -->
              <tr>
                <td>
                  <div>
                    <h3 style="font-size: 20px;margin:0px;">Hi {{user_name}} <img src="https://aviso-email-images.s3.amazonaws.com/waving-hand_1f44b.png" style="position:relative;top:6px;height:27px;width:auto;">,</h3>
                    <p style="font-size: 16px;;margin-bottom:24px;color:black;font-weight:400;margin-top:8px;">Below mentioned deals require your attention: </p>
                  </div>
                </td>
              </tr>

              <!-- Welcome user : END -->

              <!-- Content block : BEGIN -->

             </tr>




              <tr>
                <td>



                    <div style="width:512px;height:auto;background:white;padding-top:24px;">




                {% for deal in deals[:3] %}
                   <div style="width:476px;height:auto;border-radius:5px;background:white;margin-top:24px;margin-bottom:5px;">
                    <img src="https://aviso-email-images.s3.amazonaws.com/win_scores/{{deal.aviso_score|int}}.png" style="display: inline-flex;
                                width: 32px;
                                height: 32px;
                                margin: 16px 18px;
                                vertical-align: top;
                                ">
                <div style="display:inline-block;min-width:40%;max-width:80%;margin-bottom:27px;">
                <div style="font-size:15px;margin-top:15px;margin-bottom:1px;font-weight:bold;word-break: normal;display:block; ">
               <div style="font-size:14px;font-weight: 600;">
                 <a href="{{deal.update_deal_link}}" style="color:#0991cc;">{{deal.deal_name}}</a>
            </div>
            <div style="color:#6f7288;font-size:14px;font-weight:200;margin-top:0px;margin-bottom:3px;word-break: normal; ">
              Close Date: <span style="font-weight:600;">{{deal.close_date}}</span>
              <div style="width:3px;height:3px;border-radius:50%;display:inline-block;background:#6f7288;vertical-align:middle;margin-left:3px;margin-right:3px;"></div>
              Amount: <span style="font-weight:600;">{{deal.amount}}</span>
            </div>
                </div>
              </div>
              <div style="margin-left:20px;color:#6f7288;font-weight:200;font-size:12px;" id="x">
                Existing Products:<span style="color:#404255 !important;font-size:12px;font-weight:600;">{{deal.products|join(", ")}}</span>
              </div>
              <div style="margin-left:20px;color:#6f7288;font-size:12px;font-weight:200;display:flex;">

                  <img src="https://aviso-email-images.s3.amazonaws.com/info-circle.png" style="width:15px;height:14px;padding-top:2px;padding-right:6px;">

                <div style="font-size:12px;color:#6f7288;font-weight:200;">
                  Aviso recommends below mentioned products to be bundled with existing products
                </div>

              </div>




              <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="table-layout:fixed;margin-left:20px !important;margin-right:15px !important;margin-top:13.5px !important;">


              {% for item in deal.product_recommendation %}
              {%  if loop.index < 4 %}

              {% for key,value in item|dictsort(false,'value')|reverse %}
              {% if loop.index < 2 %}
              <tr>
                <td style="color:#404255;font-size:14px;font-weight:600;vertical-align:sub;width:100%;padding-bottom:8px;">
                  {{key}}
                </td>
              </tr>

              <tr>
                <td>
                <div style="color:#6f7288;font-size:12px;font-weight:200;margin-top:0px;margin-bottom:11.5px;word-break: normal;">



                  {{value}}% of closed-won deals have '{{key}}' bundled together with the mentioned products in this opportunity.

                   </div>
                </td>
              </tr>


              {%endif%}
              {%endfor%}
              {% endif %}

              {%endfor%}



                {% if  loop.index < deals|length %}
                <tr>
                  <td>
                    <div style="border: 1px solid #acb0bd"></div>
                  </td>
                  <tr>

                    {%endif%}

              </table>

              {%endfor %}

            </div>


            </div>

              </td>

              </tr>














              <!-- Content block : END -->




              <tr>
                <td>
                  <p style="color: #404255; font-size: 14px; line-height: 20.9px; text-align: center; max-width: 360px;width:251px; margin: 0 auto;margin-top:40px;">Keep up-to-date with you deals on iPhone or Android with Aviso Go.</p>
                </td>
              </tr>
              <tr>
                <td style="background-color: #f0f2f7;">
                  <div style="max-width: 360px; margin: 0 auto;">
                    <a href="https://apps.apple.com/us/app/avisogo/id1250216779" style="margin: 0px 7%;">
                      <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/Apple-AppStore_download.png" style="40px;"/>
                    </a>
                    <a href="https://play.google.com/store/apps/details?id=com.aviso.avisogo"
                       style="margin: 10px;
                             display: inline-block;
                             ">
                      <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/Android-AppStore_download.png" />
                    </a>
                  </div>
                <a href="mailto:support@aviso.com?subject=Feedback%20on%20{{nudge_name}}"><p align="center" style="font-size:13px;color:#757575;font-weight:200;">Is this email useful?  We love <span style="color:#1f9ef4;"><u>feedback!</u></span></p><a/>

                </td>
              </tr>
              <!-- 1 Column Text : END -->
            </tbody>
          </table>
        </div>
        <!-- Email Body : END -->

        <!-- Email Footer : BEGIN -->
        <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
          <tr>
            <td>
            <div style="width: 85%; border-bottom: 1px solid #c7cbd6; margin: 0 auto;"></div>
            </td>
          </tr>

          <tr>
            <td>
              <div style="width: 88%; margin: 0 auto;">
                <table role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%">
                  <tr>
                    <td style="width: 15%; padding: 5%;">
                      <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/logo_footer_red.png" />
                    </td>
                    <td style="text-align:right;">

                      <p style="color: #757575; font-size: 12px; line-height: 17.9px; text-align: right;">Copyright &copy; 2020 Aviso Inc. All rights reserved.</p>
                  </td>
                </tr>
              </table>
            </div>
          </td>
        </tr>
      </table>
      <!-- Email Footer : END -->

      <!--[if mso]>
        </td>
        </tr>
        </table>
      <![endif]-->
      </div>

      <!--[if mso | IE]>
        </td>
        </tr>
        </table>
      <![endif]-->
      <img src="{{opens_tracker}}" style="width: 1px; height: 1px">
    </center>
  </body>
</html>   
"""
subject_template = '{{(tenant_name~" -- "~nudge_name~" - " if test_mode==True else "")~" '+ 'Aviso Product Recommendations To' +'"}}'
is_html = True
name = "market_basket_nudge"
optional=["key"]

# %%
noti.api('/notify/api/email_template/', {"name": name,"subject_template":subject_template, "body_template": body_template,
                               "is_html": is_html, 'optional':optional, 'action': "create"})
# Out:
# {u'message': u'Template added successfully', u'success': True}

# %%
noti.api('/notify/api/notification/', {'action':'create', 
                                       'name' : 'market_basket_nudge',
                                       'template_name':{'email':'market_basket_nudge'}, 
                                       'template_data':{
                                        "email": ['user_name','date','deals','key','test_mode','tenant_name','nudge_name','opens_tracker']
                                        },
                                    'track_urls':[]
                                      })
# Out:
# {u'action': u'create', u'success': True}

# %%
# Out:
# {u'message': u'Event Published successfully', u'success': True}

# %%
pprint(noti.api('/notify/api/email_template/market_basket_nudge', None ))
# Out:
# {u'body_template': u'\n<!-- Hygiene -->\n<!DOCTYPE html>\n<html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:o="urn:schemas-microsoft-com:office:office">\n  <head>\n    <script src="https://kit.fontawesome.com/13244967da.js"></script>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">\n    <meta charset="utf-8"> <!-- utf-8 works for most cases -->\n    <meta name="viewport" content="width=device-width"> <!-- Forcing initial-scale shouldn\'t be necessary -->\n    <meta http-equiv="X-UA-Compatible" content="IE=edge"> <!-- Use the latest (edge) version of IE rendering engine -->\n    <meta name="x-apple-disable-message-reformatting">  <!-- Disable auto-scale in iOS 10 Mail entirely -->\n    <meta name="format-detection" content="telephone=no,address=no,email=no,date=no,url=no"> <!-- Tell iOS not to automatically link certain text strings. -->\n    <title></title> <!-- The title tag shows in email notifications, like Android 4.4. -->\n\n    <!-- Web Font / @font-face : BEGIN -->\n    <!-- NOTE: If web fonts are not required, lines 10 - 27 can be safely removed. -->\n\n    <!-- Desktop Outlook chokes on web font references and defaults to Times New Roman, so we force a safe fallback font. -->\n    <!--[if mso]>\n      <style>\n      * {\n      font-family: "Open Sans", sans-serif !important;\n      }\n      </style>\n    <![endif]-->\n\n    <!-- CSS Reset : BEGIN -->\n    <style>\n\n\n     /* What it does: Remove spaces around the email design added by some email clients. */\n     /* Beware: It can remove the padding / margin and add a background color to the compose a reply window. */\n     html,\n     body {\n         margin: 0 !important;\n         padding: 0 !important;\n         height: 100% !important;\n         width: 100% !important;\n     }\n\n     /* What it does: Stops email clients resizing small text. */\n     * {\n         -ms-text-size-adjust: 100%;\n         -webkit-text-size-adjust: 100%;\n     }\n\n     /* What it does: Centers email on Android 4.4 */\n     div[style*="margin: 16px 0"] {\n         margin: 0 !important;\n     }\n\n\n     /* What it does: Stops Outlook from adding extra spacing to tables. */\n     table,\n     td {\n         mso-table-lspace: 0pt !important;\n         mso-table-rspace: 0pt !important;\n     }\n\n     /* What it does: Fixes webkit padding issue. */\n     table {\n         border-spacing: 0 !important;\n         border-collapse: collapse !important;\n         table-layout: fixed !important;\n         margin: 0 auto !important;\n     }\n\n     /* What it does: Uses a better rendering method when resizing images in IE. */\n     img {\n         -ms-interpolation-mode:bicubic;\n     }\n\n     /* What it does: Prevents Windows 10 Mail from underlining links despite inline CSS. Styles for underlined links should be inline. */\n     a {\n         text-decoration: none;\n     }\n\n     /* What it does: A work-around for email clients meddling in triggered links. */\n     a[x-apple-data-detectors],  /* iOS */\n     .unstyle-auto-detected-links a,\n     .aBn {\n         border-bottom: 0 !important;\n         cursor: default !important;\n         color: inherit !important;\n         text-decoration: none !important;\n         font-size: inherit !important;\n         font-family: inherit !important;\n         font-weight: inherit !important;\n         line-height: inherit !important;\n     }\n\n     /* What it does: Prevents Gmail from displaying a download button on large, non-linked images. */\n     .a6S {\n         display: none !important;\n         opacity: 0.01 !important;\n     }\n\n     /* What it does: Prevents Gmail from changing the text color in conversation threads. */\n     .im {\n         color: inherit !important;\n     }\n\n     /* If the above doesn\'t work, add a .g-img class to any image in question. */\n     img.g-img + div {\n         display: none !important;\ ...
#  u'is_html': True,
#  u'name': u'market_basket_nudge',
#  u'optional': [u'key'],
#  u'subject_template': u'{{(tenant_name~" -- "~nudge_name~" - " if test_mode==True else "")~" Aviso Product Recommendations To"}}'}
