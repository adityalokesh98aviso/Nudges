# %%
import avisosdk
noti = avisosdk.connect_sdk("https://notification-qa.aviso.com")
noti.login(username='aditya@administrative.domain')
# Out:
# 2021-Apr-29 12:18:47 - INFO - Starting new HTTPS connection (1): notification-qa.aviso.com
# 2021-Apr-29 12:18:48 - INFO - No logged in session. Login first
# password?········
# Connected to url: https://notification-qa.aviso.com tenant: administrative.domain

# %%
body_template="""
<html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:o="urn:schemas-microsoft-com:office:office">

<head>
	<meta charset="utf-8">
	<!-- utf-8 works for most cases -->
	<meta name="viewport" content="width=device-width,initial-scale:1.0">
	<!-- Forcing initial-scale shouldn\'t be necessary -->
	<meta http-equiv="X-UA-Compatible" content="IE=edge">
	<!-- Use the latest (edge) version of IE rendering engine -->
	<meta name="x-apple-disable-message-reformatting">
	<!-- Disable auto-scale in iOS 10 Mail entirely -->
	<meta name="format-detection" content="telephone=no,address=no,email=no,date=no,url=no">
	<!-- Tell iOS not to automatically link certain text strings. -->
	<title></title>
	<!-- The title tag shows in email notifications, like Android 4.4. -->
	<!-- Web Font / @font-face : BEGIN -->
	<!-- NOTE: If web fonts are not required, lines 10 - 27 can be safely removed. -->
	<link href="https://fonts.googleapis.com/css?family=Open+Sans&display=swap" rel="stylesheet">
	<!-- Desktop Outlook chokes on web font references and defaults to Times New Roman, so we force a safe fallback font. -->
	<!--[if mso]>
      <style>
         * {
         font-family: 'Open Sans', sans-serif;
         }
      </style>
      <![endif]-->
	<!-- CSS Reset : BEGIN -->
	<style>
	/* What it does: Remove spaces around the email design added by some email clients. */
	/* Beware: It can remove the padding / margin and add a background color to the compose a reply window. */

	html,
	body {
		margin: 0 !important;
		padding: 0 !important;
		height: 100% !important;
		width: 100% !important;
	}
	/* What it does: Stops email clients resizing small text. */

	* {
		-ms-text-size-adjust: 100%;
		-webkit-text-size-adjust: 100%;
	}
	/* What it does: Centers email on Android 4.4 */

	div[style*="margin: 16px 0"] {
		margin: 0 !important;
	}
	/* What it does: Stops Outlook from adding extra spacing to tables. */

	table,
	td {
		mso-table-lspace: 0pt !important;
		mso-table-rspace: 0pt !important;
	}
	/* What it does: Fixes webkit padding issue. */

	table {
		border-spacing: 0 !important;
		border-collapse: collapse !important;
		table-layout: fixed !important;
		margin: 0 auto !important;
	}
	/* What it does: Uses a better rendering method when resizing images in IE. */

	img {
		-ms-interpolation-mode: bicubic;
	}
	/* What it does: Prevents Windows 10 Mail from underlining links despite inline CSS. Styles for underlined links should be inline. */

	a {
		text-decoration: none;
	}
	/* What it does: A work-around for email clients meddling in triggered links. */

	a[x-apple-data-detectors],
	/* iOS */

	.unstyle-auto-detected-links a,
	.aBn {
		border-bottom: 0 !important;
		cursor: default !important;
		color: inherit !important;
		text-decoration: none !important;
		font-size: inherit !important;
		font-family: inherit !important;
		font-weight: inherit !important;
		line-height: inherit !important;
	}
	/* What it does: Prevents Gmail from displaying a download button on large, non-linked images. */

	.a6S {
		display: none !important;
		opacity: 0.01 !important;
	}
	/* What it does: Prevents Gmail from changing the text color in conversation threads. */

	.im {
		color: inherit !important;
	}
	/* If the above doesn\'t work, add a .g-img class to any image in question. */

	img.g-img+div {
		display: none !important;
	}
	/* iPhone 4, 4S, 5, 5S, 5C, and 5SE */

	@media only screen and (min-device-width: 320px) and (max-device-width: 374px) {
		u~div .email-container {
			min-width: 320px !important;
		}
		.body-wrapper {
			padding: 1%;
		}
		.apple {
			margin: 10px 15px !important;
		}
	}
	/* iPhone 6, 6S, 7, 8, and X */

	@media only screen and (min-device-width: 375px) and (max-device-width: 413px) {
		u~div .email-container {
			min-width: 375px !important;
		}
		.body-wrapper {
			padding: 1%;
		}
		.apple {
			margin: 10px 25px !important;
		}
	}
	/* iPhone 6+, 7+, and 8+ */

	@media only screen and (min-device-width: 414px) {
		u~div .email-container {
			min-width: 414px !important;
		}
		.apple {
			margin: 10px 25px !important;
		}
	}
	</style>
	<!-- What it does: Makes background images in 72ppi Outlook render at correct size. -->
	<!--[if gte mso 9]>
      <xml>
         <o:OfficeDocumentSettings>
            <o:AllowPNG/>
            <o:PixelsPerInch>96</o:PixelsPerInch>
         </o:OfficeDocumentSettings>
      </xml>
      <![endif]-->
	<!-- Progressive Enhancements : BEGIN -->
	<style>
	/* Media Queries */

	@media screen and (max-width: 600px) {
		/* What it does: Adjust typography on small screens to improve readability */
		.email-container p {
			/*             font-size: 17px !important;*/
		}
	}
	/* custom css from here */

	@import url('https://fonts.googleapis.com/css?family=Open+Sans&display=swap');
	body {
		font-family: 'Open Sans', sans-serif;
	}

	.store-logo {
		margin-left: 7%;
		display: inline-block;
	}

	.Icon-alert,
	.Cursor-illustration {
		padding-top: 10%;
		margin: 0 auto;
		display: block;
	}

	.external-link-solid {
		margin-left: 10px;
	}

	@media only screen and (width >=768px) {
		.body-wrapper {
			padding: 6%;
		}
		.apple {
			margin: 10px 25px;
		}
	}
	</style>
	<!-- Progressive Enhancements : END -->
</head>
<!--
      The email background color (#222222) is defined in three places:
      1. body tag: for most email clients
      2. center tag: for Gmail and Inbox mobile apps and web versions of Gmail, GSuite, Inbox, Yahoo, AOL, Libero, Comcast, freenet, Mail.ru, Orange.fr
      3. mso conditional: For Windows 10 Mail
      -->

<body width="100%" style="margin: 0; padding: 0 !important; mso-line-height-rule: exactly; background-color: #ffffff;">
	<center style="width: 100%; background-color: #ffffff;">
		<!--[if mso | IE]>
         <table role="presentation" border="0" cellpadding="0" cellspacing="0" width="100%" style="background-color: #ffffff;">
         <tr>
            <td>
               <![endif]-->
		<!--
                  Set the email width. Defined in two places:
                  1. max-width for all clients except Desktop Windows Outlook, allowing the email to squish on narrow but never go wider than 560px.
                  2. MSO tags for Desktop Windows Outlook enforce a 560px width.
                  -->
		<div style="max-width: 560px; min-width: 375px; margin: 0 auto; background-color: #F0F2F7;" class="email-container">
			<table align="center" role="presentation" cellpadding="0" cellspacing="0" width="100%">
				<tr style="background-color: #151B42;">
					<td style="padding: 20px 0; text-align: center">
						<table role="presentation" cellspacing="0" cellpadding="0" width="100%">
							<tr>
								<td>
									<div style="padding: 20px;">
										<a href="https://aviso.com" rel="noreferrer" target="_blank"> <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/aviso_red.png" class="logo_gray" style=;padding-right:50px;> </a>
									</div>
								</td>
								<td style="color: #ffffff; padding: 12px;">
									<h2 style="font-size: 20px !important; margin-bottom: 0px;">Weekly Compass</h2>
									<!-- <p style="font-size: 12px !important">As of Sept 18, 2019 3:00AM</p> -->
									<div style="padding: 0 10px; font-size: 12px;">Date: {{as_of_date}}</div>
								</td>
							</tr>
						</table>
					</td>
				</tr>
			</table>
			<!-- Email Header : END -->
			<!-- Email Body : BEGIN -->
			<div class="body-wrapper" style="padding: 2%;">
				<table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
					<tbody style="background-color: #F0F2F7; border: 13px solid transparent;">
						<!-- Welcome user : BEGIN -->
						<tr>
							<td>
								<table role="presentation" cellpadding="0" cellspacing="0" width="100%">
									<tr>
										<td>
											<table style="margin: 10px auto 0 8% !important;">
												<tr>
													<td>
														<h3 style="font-size: 20px;margin:0px;position:relative;left:10px;">
                                                Hi {{name}} <img
                                                   src="https://aviso-email-images.s3.amazonaws.com/waving-hand_1f44b.png"
                                                   style="position:relative;top:6px;height:27px;width:auto;">,
                                             </h3> </td>
												</tr>
											</table>
										</td>
										<td>
											<table style="margin: 20px 8% 0 auto !important;">
												<tr>
													<td>
														<div>
															<p style="color: #404255; font-size: 13px; text-align: right;"> <b>{{days_to_eoq}}</b> Days left in the quarter </p>
															<!-- Progress bar using div -->
															<!-- Maniputlate the width of inner div -->
															<div style="background-color: #dde0eb; height: 15px; border-radius: 10px; width: 113px; margin: 0 0 0 auto;">
																<div style="width:{{percent_completed}}%; height: 15px; background-color: #6e77c2; border-radius: 10px;"> </div>
															</div>
														</div>
													</td>
												</tr>
											</table>
										</td>
									</tr>
								</table>
							</td>
						</tr>
						<!-- Welcome user : END -->
						<!-- Hierarchy : BEGIN -->
						<!-- Hierarchy : END -->
						<!-- Top Block : BEGIN-->
						<!-- Top Block : END -->
						{% for persona in pivot_payload %}
						<tr>
							<td>
							  <div style="border-radius: 5px;margin: 10px 6% 10px;margin-bottom: 0px;padding-bottom: 15px;background-color: #ffffff;padding-top: 20px;border: 1px solid #dde0eb;">
								<p style="text-align:center;font-size: 18px;font-weight: bolder; color: #404255;margin-top: 15px;margin-bottom:15px;"> Forecast for the quarter </p>
								{% if persona.covid_enabled %}
								<p style="text-align:center;font-size:12px; padding: 10px 40px;color:#6f7288;padding:0px;margin-top:4px;"> With Covid-19, Aviso is projecting an impact of
								  <br /> <span style="color:#d60651;font-weight:bold;"> {{persona.covid_aviso_difference_amount }}
												{% endif %}
								  <table role="presentation" align="center" cellpadding="0" cellspacing="0" border="0" width="90%">
									<col width="50%">
									  <col width="50%">
										<tr>
										  <td> &nbsp; </td>
										</tr>
										<tr>
										  <td style="font-size:14px;font-weight:600;color: #404255;"> {{ persona.plan_value.label|upper }}  </td>
										  <td style="text-align:right;color:#232742;font-size:22px;font-weight: bold;"> {{ persona.plan_value.value }} </td>
										</tr>

										<tr>
										  <td> &nbsp; </td>
										</tr>
										<tr>
										  <td>
											<div style="width: 100%; border-bottom: 1px solid  #dde0eb; margin: 0 auto;"> </div>
										  </td>
										  <td>
											<div style="width: 100%; border-bottom: 1px solid  #dde0eb; margin: 0 auto;"> </div>
										  </td>
										</tr>
										<tr>
										  <td> &nbsp; </td>
										</tr>
										<tr>
										  <td style="font-size:14px;font-weight:600;color: #404255;"> <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/logo_footer_red.png" alt="aviso_logo" style="width: 16px;height: 16px;padding-right: 5px; vertical-align: top;" /> AI FORECAST </td>
										  <td style="text-align:right;color:#232742;font-size:22px;font-weight: bold;"> {{ persona.aviso_forecast }} </td>
										</tr>

										<tr>
										  <td> &nbsp; </td>
										</tr>
										<tr>
										  <td>
											<div style="width: 100%; border-bottom: 1px solid  #dde0eb; margin: 0 auto;"> </div>
										  </td>
										  <td>
											<div style="width: 100%; border-bottom: 1px solid  #dde0eb; margin: 0 auto;"> </div>
										  </td>
										</tr>
										<tr>
										  <td> &nbsp; </td>
										</tr> {% if persona.covid_enabled %}
										<tr>
										  <td style="font-size:14px;font-weight:600;color: #404255;">{{persona.booked_value.label|upper}}</td>
										  <td  style="text-align:right;color:#232742;font-size:22px;font-weight: bold;"> {{ persona.booked_value.value }} </td>
										</tr>
										{%endif%}
										<tr>
											<td> &nbsp; </td>
										  </tr>

										<tr>
										  <td>
											<div style="width: 100%; border-bottom: 1px solid  #dde0eb; margin: 0 auto;"> </div>
										  </td>
										  <td>
											<div style="width: 100%; border-bottom: 1px solid  #dde0eb; margin: 0 auto;"> </div>
										  </td>
										</tr>
										<tr>
										  <td> &nbsp; </td>
										</tr>
										<tr>
										  <td style="font-size:14px;font-weight:600;color: #404255;">TO GO NUMBERS </td>
										  <td rowspan="2" style="text-align:right;color:#232742;font-size:22px;font-weight: bold;"> {{ persona.to_go_numbers}} </td>
										</tr>
										<tr>
											<td> &nbsp; </td>
										  </tr>
										<tr>
										<td colspan="2">
											<a href="{{persona.dashboard_link}}" style="margin:auto;line-height:5px;background: #151b42;border: 1px solid #151B42; font-family: Open Sans Regular, sans-serif; font-size: 10pt;font-weight:400;text-decoration: none; padding: 13px 17px; color: #ffffff; display: block;margin-bottom:0px;border-radius: 4px; text-align: center; width: 50%;margin-top:14px;">View Trend
											</a>
										</td>
										</tr>


								  </table>
							  </div>
							</td>
						  </tr>
						  <tr>
							<td>
							  <div style="border-radius: 5px;margin: 10px 6% 10px;margin-bottom: 0px;padding-bottom: 15px;background-color: #ffffff;padding-top: 20px;border: 1px solid #dde0eb;">
								<p style="text-align:center;font-size: 18px;font-weight: bolder; color: #404255;margin-top:0px;margin-bottom:15px;"> TCV Deals for the Quarter </p>
								  <table role="presentation" align="center" cellpadding="8.5" cellspacing="0" border="0" width="90%">
									<col width="30%">
									<col width="19%">
									<col width="15%">
									<col width="15%">
										<tr>
										  <td>
											&nbsp;
										  </td>
										  <td style="color:#404255;font-size: 12px;font-weight: bolder;text-align: center;">
											$1M TCV DEALS COUNT
										  </td>
										  <td style="color:#404255;font-size: 12px;font-weight:bolder;text-align:center;">
											TCV  AMOUNT
										  </td>
										  <td style="color:#404255;font-size: 12px;font-weight:bolder;text-align:center;">
											ARR  AMOUNT
										  </td>

										</tr>
										<tr>
										  <td style="font-size: 14px;color:#404255;font-weight:bolder;">
											TOTAL DEALS
										  </td>
										  <td style="color:#404255;font-size: 12px;font-weight: bolder;text-align: center;">
											{{persona.TCV_deals.TCV_total_deals.count}} deals
										  </td>
										  <td style="color:#404255;font-size: 12px;font-weight:bolder;text-align:center;">
											{{persona.TCV_deals.TCV_total_deals.TCV_amount}}
										  </td>
										  <td style="color:#404255;font-size: 12px;font-weight:bolder;text-align:center;">
											{{persona.TCV_deals.TCV_total_deals.ARR_amount}}
										  </td>
										</tr>
										<tr>
											<td style="font-size: 14px;color:#404255;font-weight:bolder;">
											  WON
											</td>
											<td style="color:#404255;font-size: 12px;font-weight: bolder;text-align: center;">
											  {{persona.TCV_deals.qtr_TCV_won_deals.count}} deals
											</td>
											<td style="color:#404255;font-size: 12px;font-weight: bolder;text-align:center;">
											  {{persona.TCV_deals.qtr_TCV_won_deals.TCV_amount}}
											</td>
											<td style="color:#404255;font-size: 12px;font-weight: bolder;text-align:center;">
											  {{persona.TCV_deals.qtr_TCV_won_deals.ARR_amount}}
											</td>
										  </tr>
										  <tr>
											<td style="font-size: 14px;color:#404255;font-weight:bolder;">
											  LOST
											</td>
											<td style="color:#404255;font-size: 12px;font-weight: bolder;text-align: center;">
											  {{persona.TCV_deals.qtr_TCV_lost_deals.count}} deals
											</td>
											<td style="color:#404255;font-size: 12px;font-weight: bolder;text-align:center;">
											  {{persona.TCV_deals.qtr_TCV_lost_deals.TCV_amount}}
											</td>
											<td style="color:#404255;font-size: 12px;font-weight: bolder;text-align:center;">
											  {{persona.TCV_deals.qtr_TCV_lost_deals.ARR_amount}}
											</td>
										  </tr>
										  <tr>
											<td style="font-size: 14px;color:#404255;font-weight:bolder;">
											  PIPELINE
											</td>
											<td style="color:#404255;font-size: 12px;font-weight: bolder;text-align: center;">
											  {{persona.TCV_deals.TCV_pipeline_deals.count}} deals
											</td>
											<td style="color:#404255;font-size: 12px;font-weight: bolder;text-align:center;">
											  {{persona.TCV_deals.TCV_pipeline_deals.TCV_amount}}
											</td>
											<td style="color:#404255;font-size: 12px;font-weight: bolder;text-align:center;">
											  {{persona.TCV_deals.TCV_pipeline_deals.ARR_amount}}
											</td>
										  </tr>

										  <tr>
											<td colspan="4">
												<a href="{{persona.dashboard_link}}" style="margin:auto;line-height:5px;background: #151b42;border: 1px solid #151B42; font-family: Open Sans Regular, sans-serif; font-size: 10pt;font-weight:400;text-decoration: none; padding: 13px 17px; color: #ffffff; display: block;margin-bottom:0px;border-radius: 4px; text-align: center; width: 50%;margin-top:14px;">View Deals
												</a>
											</td>
											</tr>

								  </table>
							  </div>
							</td>
						  </tr>
						  <tr>
							<td>
							  <div style="border-radius: 5px;margin: 10px 6% 10px;margin-bottom: 0px;padding-bottom: 15px;background-color: #ffffff;padding-top: 20px;border: 1px solid #dde0eb;">
								<p style="text-align:center;font-size: 18px;font-weight: bolder; color: #404255;margin-top: 0px;margin-bottom:15px;"> TCV Deals for the Day </p>
								  <table role="presentation" align="center" cellpadding="8.5" cellspacing="0" border="0" width="90%">
									<col width="30%">
									<col width="19%">
									<col width="15%">
									<col width="15%">
										<tr>
										  <td>
											&nbsp;
										  </td>
										  <td style="color:#404255;font-size: 12px;font-weight: bolder;text-align: center;">
											$1M TCV DEALS COUNT
										  </td>
										  <td style="color:#404255;font-size: 12px;font-weight:bolder;text-align:center;">
											TCV  AMOUNT
										  </td>
										  <td style="color:#404255;font-size: 12px;font-weight:bolder;text-align:center;">
											ARR  AMOUNT
										  </td>

										</tr>
										<tr>
										  <td style="font-size: 14px;color:#404255;font-weight:bolder;">
											WON
										  </td>
										  <td style="color:#404255;font-size: 12px;font-weight: bolder;text-align: center;">
											{{persona.TCV_deals.TCV_won_deals.count}} deals
										  </td>
										  <td style="color:#404255;font-size: 12px;font-weight:bolder;text-align:center;">
											{{persona.TCV_deals.TCV_won_deals.TCV_amount}}
										  </td>
										  <td style="color:#404255;font-size: 12px;font-weight:bolder;text-align:center;">
											{{persona.TCV_deals.TCV_won_deals.ARR_amount}}
										  </td>
										</tr>
										<tr>
											<td colspan="4">
												<a href="{{persona.dashboard_link}}" style="margin:auto;line-height:5px;background: #151b42;border: 1px solid #151B42; font-family: Open Sans Regular, sans-serif; font-size: 10pt;font-weight:400;text-decoration: none; padding: 13px 17px; color: #ffffff; display: block;margin-bottom:0px;border-radius: 4px; text-align: center; width: 50%;margin-top:14px;">View Deals
												</a>
											</td>
											</tr>
								  </table>
							  </div>
							</td>
						  </tr>


						{% endfor %}
						<!--  END :: Executive Template -->
						<!-- Clear Spacer : BEGIN -->
						<tr>
							<td colspan=1>
								<p style="text-align:center;font-weight:bold;font-size:13px;margin-top:10px">Want Aviso on the go ?</p>
							</td>
						</tr>
						<tr>
							<td style="background-color: #F0F2F7;">
								<div style="max-width: 360px; margin: 10px auto;">
									<table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
										<tr>
											<td style="padding: 0 10%;">
												<a href="https://apps.apple.com/us/app/avisogo/id1250216779" rel="noreferrer" target="_blank"> <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/Apple-AppStore_download.png" class="apple-store" style="height: 33px;"> </a>
											</td>
											<td style="padding: 0 5%;">
												<a href="https://play.google.com/store/apps/details?id=com.aviso.avisogo" rel="noreferrer" target="_blank"> <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/Android-AppStore_download.png" class="play-store" style="height: 33px;"> </a>
											</td>
										</tr>
									</table>
								</div>
							</td>
						</tr>
						<!-- Email Body : END -->
						<!-- Email Footer : BEGIN -->
						<tr>
						<td>
						<table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
							<tr>
								<td>
									<div style="width: 93%; border-bottom: 1px solid #C7CBD6; margin: 0 auto;"></div>
								</td>
							</tr>
							<tr>
								<td>
									<div style="width: 86%; margin: 20px auto;">
										<table role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%">
											<tr>
												<td>
													<a href="https://aviso.com" rel="noreferrer" target="_blank"> <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/logo_footer_red.png" class="Logo_Footer"> </a>
												</td>
												<td>
													<p style="color: #757575; font-size: 12px; line-height: 17.9px; text-align: right;"> Copyright &copy; 2021 Aviso AI
														<br />All rights reserved. </p>
												</td>
											</tr>
										</table>
									</div>
								</td>
							</tr>
						</table>
						</td>
						</tr>
					</tbody>
				</table>
				</div>
			</div>
	</center>
  <img src="{{opens_tracker}}" style="width: 1px; height: 1px">
</body>
</html>
"""
subject_template = "Hello, Your Weekly Compass powered by Aviso AI is ready to view"
is_html = True
name = "ring_central_email_digest"
optional = ['as_of_date', 'name', 'days_to_eoq' ,'meet_link','percent_completed','pivot_payload','opens_tracker']

# %%
noti.api('/notify/api/email_template/', {"name": name,"subject_template":subject_template, "body_template": body_template,
                               "is_html": is_html, 'optional':optional, 'action': "create"} )
# Out:
# {u'message': u'Template added successfully', u'success': True}

# %%
noti.api('/notify/api/notification/', {'action':'create', 
                                       'name' : 'ring_central_email_digest',
                                       'template_name':{'email':'ring_central_email_digest'}, 
                                       'template_data':{
                                        "email": ['as_of_date', 'name', 'days_to_eoq' ,'percent_completed','pivot_payload','opens_tracker']
                                        },
                                         'track_urls':[]
                                      })
# Out:
# {u'action': u'create', u'success': True}

# %%
# Out:
# {u'message': u'Event Published successfully', u'success': True}
