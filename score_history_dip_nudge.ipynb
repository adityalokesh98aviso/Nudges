# %%
import avisosdk
noti = avisosdk.connect_sdk("https://notification-qa.aviso.com")
noti.login(username='aditya@administrative.domain')
# Out:
# [PID] 2021-Apr-08 12:56:05 - INFO - Starting new HTTPS connection (1): notification-qa.aviso.com
# [PID] 2021-Apr-08 12:56:06 - INFO - No logged in session. Login first
# password?········
# Connected to url: https://notification-qa.aviso.com tenant: administrative.domain

# %%
body_template="""

<!DOCTYPE html>
<html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:o="urn:schemas-microsoft-com:office:office">
  <head>
    <meta charset="utf-8"> <!-- utf-8 works for most cases -->
    <meta name="viewport" content="width=device-width"> <!-- Forcing initial-scale shouldn't be necessary -->
    <meta http-equiv="X-UA-Compatible" content="IE=edge"> <!-- Use the latest (edge) version of IE rendering engine -->
    <meta name="x-apple-disable-message-reformatting">  <!-- Disable auto-scale in iOS 10 Mail entirely -->
    <meta name="format-detection" content="telephone=no,address=no,email=no,date=no,url=no"> <!-- Tell iOS not to automatically link certain text strings. -->
    <title></title> <!-- The title tag shows in email notifications, like Android 4.4. -->

    <!-- Web Font / @font-face : BEGIN -->
    <!-- NOTE: If web fonts are not required, lines 10 - 27 can be safely removed. -->

    <!-- Desktop Outlook chokes on web font references and defaults to Times New Roman, so we force a safe fallback font. -->
    <!--[if mso]>
      <style>
      * {
      font-family: "Open Sans", sans-serif !important;
      }
      </style>
    <![endif]-->

    <!-- CSS Reset : BEGIN -->
    <style>

     /* What it does: Remove spaces around the email design added by some email clients. */
     /* Beware: It can remove the padding / margin and add a background color to the compose a reply window. */
     html,
     body {
         margin: 0 !important;
         padding: 0 !important;
         height: 100% !important;
         width: 100% !important;
     }

     /* What it does: Stops email clients resizing small text. */
     * {
         -ms-text-size-adjust: 100%;
         -webkit-text-size-adjust: 100%;
     }

     /* What it does: Centers email on Android 4.4 */
     div[style*="margin: 16px 0"] {
         margin: 0 !important;
     }

     /* What it does: Stops Outlook from adding extra spacing to tables. */
     table,
     td {
         mso-table-lspace: 0pt !important;
         mso-table-rspace: 0pt !important;
     }

     /* What it does: Fixes webkit padding issue. */
     table {
         border-spacing: 0 !important;
         border-collapse: collapse !important;
         table-layout: fixed !important;
         margin: 0 auto !important;
     }

     /* What it does: Uses a better rendering method when resizing images in IE. */
     img {
         -ms-interpolation-mode:bicubic;
     }

     /* What it does: Prevents Windows 10 Mail from underlining links despite inline CSS. Styles for underlined links should be inline. */
     a {
         text-decoration: none;
     }

     /* What it does: A work-around for email clients meddling in triggered links. */
     a[x-apple-data-detectors],  /* iOS */
     .unstyle-auto-detected-links a,
     .aBn {
         border-bottom: 0 !important;
         cursor: default !important;
         color: inherit !important;
         text-decoration: none !important;
         font-size: inherit !important;
         font-family: inherit !important;
         font-weight: inherit !important;
         line-height: inherit !important;
     }

     /* What it does: Prevents Gmail from displaying a download button on large, non-linked images. */
     .a6S {
         display: none !important;
         opacity: 0.01 !important;
     }

     /* What it does: Prevents Gmail from changing the text color in conversation threads. */
     .im {
         color: inherit !important;
     }

     /* If the above doesn't work, add a .g-img class to any image in question. */
     img.g-img + div {
         display: none !important;
     }

     /* iPhone 4, 4S, 5, 5S, 5C, and 5SE */
     @media only screen and (min-device-width: 320px) and (max-device-width: 374px) {
         u ~ div .email-container {
             min-width: 320px !important;
         }

         .body-wrapper {
             padding: 1%;
         }

         .apple {
             margin: 10px 15px !important;
         }
     }
     /* iPhone 6, 6S, 7, 8, and X */
     @media only screen and (min-device-width: 375px) and (max-device-width: 413px) {
         u ~ div .email-container {
             min-width: 375px !important;
         }

         .body-wrapper {
             padding: 1%;
         }

         .apple {
             margin: 10px 25px !important;
         }
     }
     /* iPhone 6+, 7+, and 8+ */
     @media only screen and (min-device-width: 414px) {
         u ~ div .email-container {
             min-width: 414px !important;
         }

         .apple {
             margin: 10px 25px !important;
         }
     }

    </style>

    <!-- What it does: Makes background images in 72ppi Outlook render at correct size. -->
    <!--[if gte mso 9]>
      <xml>
      <o:OfficeDocumentSettings>
      <o:AllowPNG/>
      <o:PixelsPerInch>96</o:PixelsPerInch>
      </o:OfficeDocumentSettings>
      </xml>
    <![endif]-->

    <!-- Progressive Enhancements : BEGIN -->
    <style>

     /* Media Queries */
     @media screen and (max-width: 600px) {

         /* What it does: Adjust typography on small screens to improve readability */
         .email-container p {
             /*             font-size: 17px !important;*/
         }

     }

     /* custom css from here */

     body {
         font-family: "Open Sans", sans-serif;
     }

     .block_wrapper {
         border: 1px solid #d4d4d4;
         border-radius: 5px;
         margin: 10px 5% 10px;
         padding-bottom: 15px;
     }

     .store-logo {
         margin: 10px;
         display: inline-block;
     }

     .section-heading {
         color: #757575;
         font-size: 10px;
         padding: 5px;
     }

     .section-content {
         color: #424242;
         font-size: 14px;
         padding: 5px;
     }

     @media only screen and (width >= 768px) {

         .body-wrapper {
             padding: 6%;
         }

         .apple {
             margin: 10px 25px;
         }
     }


    </style>
    <!-- Progressive Enhancements : END -->

  </head>
  <!--
       The email background color (#222222) is defined in three places:
       1. body tag: for most email clients
       2. center tag: for Gmail and Inbox mobile apps and web versions of Gmail, GSuite, Inbox, Yahoo, AOL, Libero, Comcast, freenet, Mail.ru, Orange.fr
       3. mso conditional: For Windows 10 Mail
  -->
  <body width="100%" style="margin: 0; padding: 0 !important; mso-line-height-rule: exactly; background-color: #ffffff;">
    <center style="width: 100%; background-color: #ffffff;">
      <!--[if mso | IE]>
        <table role="presentation" border="0" cellpadding="0" cellspacing="0" width="100%" style="background-color: #ffffff;">
        <tr>
        <td>
      <![endif]-->

      <!--
           Set the email width. Defined in two places:
           1. max-width for all clients except Desktop Windows Outlook, allowing the email to squish on narrow but never go wider than 600px.
           2. MSO tags for Desktop Windows Outlook enforce a 600px width.
      -->
      <div style="max-width: 560px; min-width: 375px; margin: 0 auto; background-color: #F0F2F7;" class="email-container">
        <!--[if mso]>
          <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="600">
          <tr>
          <td>
        <![endif]-->

        <!-- Email Header : BEGIN -->

        <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
          <tr style="background-color: #151b42;">
            <td style="padding: 20px 0; text-align: center">
              <table role="presentation" cellspacing="0" cellpadding="0" width="100%">
                <tr>
                  <td>
                    <div style="padding: 20px;">
                      <a href="https://aviso.com" rel="noreferrer" target="_blank">
                        <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/aviso_red.png" />
                      </a>
                    </div>
                  </td>
                  <td style="color: #ffffff;">

                    <span style="font-size: 20px !important; font-weight: bold; display: inline-block; margin-bottom: 5px; margin-left: 10px; vertical-align: bottom;">Deal Health</span>
                  </td>
                </tr>
              </table>
            </td>
          </tr>
        </table>
        <!-- Email Header : END -->

        <!-- Email Body : BEGIN -->
        <div style="padding: 3% 5%;">
          <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
            <tbody style="background-color: #F0F2F7; border: 13px solid transparent;">
              <!-- Welcome user : BEGIN -->
              <tr>
                <td>
                  <div>
                    <h3 style="font-size: 20px;margin:0px;">Hi {{user_name}} <img src="https://aviso-email-images.s3.amazonaws.com/waving-hand_1f44b.png" style="position:relative;top:6px;height:27px;width:auto;">,</h3>
                    <p style="font-size: 15px;margin-bottom:20px;color:black;font-weight:400;margin-top:8px;">Aviso identified {{deals|length}} deals that need your attention:</p>
                  </div>
                </td>
              </tr>
              <!-- Welcome user : END -->

              <!-- Content block : BEGIN -->
              <tr>
                <td>
                  {% for deal in deals %}
                  <div style="background-color: #ffffff;padding-top:15.5px;">
                    <div>

                    <div style="margin: 0px 22px 0 22px;display: flex;align-items: center;background:#ffefef;padding: 8px 12px;font-size: 12px;border-radius: 4px;"><!--f3fcf7 -->

                      <div style="font-family: OpenSans;font-size: 14px;color:#6f7288;">
                          <span style="font-weight:200;">Aviso Score has dropped from {{deal.score_prev}} to {{deal.aviso_score}} which indicates a risk of losing this deal. </span>

                      </div>
                  </div>
                    <img src = "https://aviso-email-images.s3.amazonaws.com/win_scores/{{deal.aviso_score}}.png"style="display: inline-flex;
                                width: 32px;
                                height: 32px;
                                margin: 20px 22px;
                                vertical-align: top;
                                ">
                    <div style="display: inline-block; min-width: 50%; width: 70%;">
                        <h2 style="font-size: 14px;font-weight: 600; padding:2px; margin-bottom: 0;padding-bottom: 0px;margin-bottom:8px;">
                          <a  href="{{deal.update_deal_link}}" style="color: #0991cc;">{{deal.deal_name}}</a></h2>
                      <p style="color: #404255;
                                font-size: 12px;
                                padding: 2px;
                                font-weight:200;
                                margin: 0;
                                margin-bottom:14px;
                                ">Owner :<span style="font-weight:600;"> {{deal.deal_owner}}</span></p>



                          <p style="color: #6f7288;
                                     font-size: 12px;
                                     padding: 2px;
                                       margin: 0px;
                                       font-weight:200;
                                     ">
                                     {% if tenant_name == 'conviva' %}
                                        Net New Arr:
                                     {% else %}
                                        Amount:
                                     {% endif %}
                                     <span style="font-weight:600;">{{deal.amount}}
                                   </p>
                          <p style="color: #6f7288;
                                     font-size: 12px;
                                     padding: 2px;
                                      margin: 0px;
                                      font-weight: 200;
                                      margin-bottom: 15.5px;
                                     ">Close Date:<span style="color:#6f7288;font-weight:600;">{{deal.close_date}}</span></p>











                    <!-- <div style="width: 90%; border-bottom: 1px solid #757575; margin: 10px auto;"></div> -->
                    <!-- <div style="font-size: 14px; color: #404255; width: 84%; margin: 0 auto;">
                      <p style="color: #3f5469;"><b>Deal Insights:</b></p>
                      <table role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
                        <tr>
                          <td style="width: 8%;">
                            <img src="https://aviso-email-images.s3.amazonaws.com/chevron-circle-up-solid 2.png" width="15.5px" height="15.5px" style="display: inline-block; margin-top: 2px;" />

                          </td>
                          <td>
                            <p style="margin-left: 5%;">This is an insight</p>
                              </td>
                            </tr>

                      </table>
                    </div> -->

                </div>
                {% if loop.index <  deals|length %}
                <div style="width: 91%; border-bottom: 1px solid #dde0eb; margin: 0 auto;"></div>
                {% endif %}

              </div>
              {% endfor %}
            </div>
              <div style="background:#ffffff;padding-bottom:28px;">


              <a href="{{view_all_deals}}" style="margin:auto;line-height:5px;background: #3d4689;border: 1px solid #151B42; font-family: Open Sans Regular, sans-serif; font-size: 11pt;font-weight: 400;text-decoration: none; padding: 13px 17px; color: #ffffff; display: block;margin-bottom:0px;border-radius: 4px; text-align: center; width:28%;">View all Deals
              </a>
            </div>
                </td>
              </tr>
              <!-- Content block : END -->
              <!-- Clear Spacer : BEGIN -->
              <tr>
                <td aria-hidden="true" height="40" style="font-size: 0px; line-height: 0px;">
                  &nbsp;
                </td>
              </tr>
              <!-- Clear Spacer : END -->

              <!-- 1 Column Text : BEGIN -->
              <tr>
                <td>
                  <p style="color: #404255; font-size: 14px; line-height: 20.9px; text-align: center; max-width: 360px; margin: 0 auto;">Keep up-to-date with you deals on iPhone or Android with Aviso Go.</p>
                </td>
              </tr>
              <tr>
                <td style="background-color: #f0f2f7;">
                  <div style="max-width: 360px; margin: 0 auto;">
                    <a href="https://apps.apple.com/us/app/avisogo/id1250216779" style="margin: 0px 7%;">
                      <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/Apple-AppStore_download.png" style="40px;"/>
                    </a>
                    <a href="https://play.google.com/store/apps/details?id=com.aviso.avisogo"
                       style="margin: 10px;
                             display: inline-block;
                             ">
                      <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/Android-AppStore_download.png" />
                    </a>
                  </div>
                    <a href="mailto:support@aviso.com?subject=Feedback%20on%20{{nudge_name}}"><p align="center" style="font-size:13px;color:#757575;font-weight:200;">Is this email useful?  We love <span style="color:#1f9ef4;"><u>feedback!</u></span></p><a/>
                </td>
              </tr>
              <!-- 1 Column Text : END -->
            </tbody>
          </table>
        </div>
        <!-- Email Body : END -->

        <!-- Email Footer : BEGIN -->
        <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
          <tr>
            <td>
              <div style="width: 88%; border-bottom: 1px solid #C7CBD6; margin: 0 auto;"></div>
            </td>
          </tr>

          <tr>
            <td>
              <div style="width: 88%; margin: 0 auto;">
                <table role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%">
                  <tr>
                    <td style="widht: 15%; padding: 5%;">
                      <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/logo_footer_red.png" />
                    </td>
                    <td>

                      <p style="color: #757575; font-size: 12px; line-height: 17.9px; text-align: right;">Copyright &copy; 2020 Aviso Inc. All rights reserved.</p>
                  </td>
                </tr>
              </table>
            </div>
          </td>
        </tr>
      </table>
      <!-- Email Footer : END -->

      <!--[if mso]>
        </td>
        </tr>
        </table>
      <![endif]-->
      </div>

      <!--[if mso | IE]>
        </td>
        </tr>
        </table>
      <![endif]-->
    </center>
    <img src="{{opens_tracker}}" style="width: 1px; height: 1px">
  </body>
</html> 
"""
subject_template = '{{(tenant_name~" -- "~nudge_name~" - " if test_mode==True else "")~" Deal found that had a drop in the Aviso Score"}}'
is_html = True
name = "score_history_dip_nudge"
optional = [u'test_mode', u'tenant_name', u'nudge_name']

# %% [markdown]
# # Add Template

# %%
noti.api('/notify/api/email_template/', {"name": name,"subject_template":subject_template, "body_template": body_template,
                               "is_html": is_html, 'optional':optional, 'action': "update"} )
# Out:
# {u'message': u'Template added successfully', u'success': True}

# %% [markdown]
# # Add notification Type

# %%
noti.api('/notify/api/notification/', {'action':'create', 
                                       'name' : 'score_history_dip_nudge',
                                       'template_name':{'email':'score_history_dip_nudge'}, 
                                       'template_data':{
                                        "email": ['user_name', 'view_all_deals','deals', 'opens_tracker', 'test_mode', 'tenant_name', 'nudge_name']
                                        },
                                    'track_urls':[]
                                      })
# Out:
# {u'action': u'create', u'success': True}

# %%
event_name ='score_history_dip_nudge'
payload ={
    "tenant_name":'aditya',
    "nudge_name":'non commit',
    "test_mode": True,
"user_name":"Final Nudge",
    "deals":[{
            "score_prev":26,
            "aviso_score":24,
            "deal_name":"Nike License Contract 500 deals the changes can be made as nessecary and the text is adjustable as needed ",
            "deal_owner":"Nike incorporated",
            "amount":"$24,345,23",
            "close_date":"25th Jan 2020",
            "message":"The new message",
            "no_of_change":4,
            "update_deal_link":"https://www.abc.com",
            
        },
             {
            "score_prev":36,
            "aviso_score":21,
            "deal_name":"Velo deal signoff 600 deals the changes are not as needed and the changes can be be made as needed theese are the demands ",
            "deal_owner":"Velo Licenses ",
            "amount":"$12,234,67",
            "close_date":"30 march 2020",
            "message":"This is the new message",
            "no_of_change":4,
            "update_deal_link":"https://www.def.com",
            
        },
             {
            "score_prev":45,
            "aviso_score":87,
            "deal_name":"new License working nudge the ",
            "deal_owner":"navita singh",
            "amount":"$125,324,33",
            "close_date":"28th Feb 2020",
            "no_of_change":4,
            "message":"sample message",
            "update_deal_link":"https://www.abc.com",
            
        },
            
       ],
     
"no_of_deals":3,
"view_all_deals":'https:www.abc.com',
"opens_tracker":"abc.com",
"recipients": "aditya.lokesh@aviso.com",
"skip_header_footer": True,
    }
noti.api('/notify/api/test_notification', {'event_name': event_name, 'payload': payload})
# Out:
# {u'message': u'Event Published successfully', u'success': True}

# %%
pprint(noti.api('/notify/api/email_template/score_history_dip_nudge', None ))
# Out:
# {u'body_template': u'\n<!-- Good news -->\n<!DOCTYPE html>\n<html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:o="urn:schemas-microsoft-com:office:office">\n  <head>\n    <meta charset="utf-8"> <!-- utf-8 works for most cases -->\n    <meta name="viewport" content="width=device-width"> <!-- Forcing initial-scale shouldn\'t be necessary -->\n    <meta http-equiv="X-UA-Compatible" content="IE=edge"> <!-- Use the latest (edge) version of IE rendering engine -->\n    <meta name="x-apple-disable-message-reformatting">  <!-- Disable auto-scale in iOS 10 Mail entirely -->\n    <meta name="format-detection" content="telephone=no,address=no,email=no,date=no,url=no"> <!-- Tell iOS not to automatically link certain text strings. -->\n    <title></title> <!-- The title tag shows in email notifications, like Android 4.4. -->\n\n    <!-- Web Font / @font-face : BEGIN -->\n    <!-- NOTE: If web fonts are not required, lines 10 - 27 can be safely remov
# ...
