# %%
import avisosdk
noti = avisosdk.connect_sdk("https://notification-qa.aviso.com")
noti.login(username='aditya@administrative.domain')
# Out:
# 2021-Mar-09 11:06:50 - INFO - Starting new HTTPS connection (1): notification-qa.aviso.com
# 2021-Mar-09 11:06:51 - INFO - No logged in session. Login first
# password?········
# Connected to url: https://notification-qa.aviso.com tenant: administrative.domain

# %%
body_template="""
<!-- Hygiene -->
<!DOCTYPE html>
<html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:o="urn:schemas-microsoft-com:office:office">
  <head>
    <script src="https://kit.fontawesome.com/13244967da.js"></script>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
    <meta charset="utf-8"> <!-- utf-8 works for most cases -->
    <meta name="viewport" content="width=device-width"> <!-- Forcing initial-scale shouldn't be necessary -->
    <meta http-equiv="X-UA-Compatible" content="IE=edge"> <!-- Use the latest (edge) version of IE rendering engine -->
    <meta name="x-apple-disable-message-reformatting">  <!-- Disable auto-scale in iOS 10 Mail entirely -->
    <meta name="format-detection" content="telephone=no,address=no,email=no,date=no,url=no"> <!-- Tell iOS not to automatically link certain text strings. -->
    <title></title> <!-- The title tag shows in email notifications, like Android 4.4. -->

    <!-- Web Font / @font-face : BEGIN -->
    <!-- NOTE: If web fonts are not required, lines 10 - 27 can be safely removed. -->

    <!-- Desktop Outlook chokes on web font references and defaults to Times New Roman, so we force a safe fallback font. -->
    <!--[if mso]>
      <style>
      * {
      font-family: "Open Sans", sans-serif !important;
      }
      </style>
    <![endif]-->

    <!-- CSS Reset : BEGIN -->
    <style>

     /* What it does: Remove spaces around the email design added by some email clients. */
     /* Beware: It can remove the padding / margin and add a background color to the compose a reply window. */
     html,
     body {
         margin: 0 !important;
         padding: 0 !important;
         height: 100% !important;
         width: 100% !important;
     }

     /* What it does: Stops email clients resizing small text. */
     * {
         -ms-text-size-adjust: 100%;
         -webkit-text-size-adjust: 100%;
     }

     /* What it does: Centers email on Android 4.4 */
     div[style*="margin: 16px 0"] {
         margin: 0 !important;
     }

     /* What it does: Stops Outlook from adding extra spacing to tables. */
     table,
     td {
         mso-table-lspace: 0pt !important;
         mso-table-rspace: 0pt !important;
     }

     /* What it does: Fixes webkit padding issue. */
     table {
         border-spacing: 0 !important;
         border-collapse: collapse !important;
         table-layout: fixed !important;
         margin: 0 auto !important;
     }

     /* What it does: Uses a better rendering method when resizing images in IE. */
     img {
         -ms-interpolation-mode:bicubic;
     }

     /* What it does: Prevents Windows 10 Mail from underlining links despite inline CSS. Styles for underlined links should be inline. */
     a {
         text-decoration: none;
     }

     /* What it does: A work-around for email clients meddling in triggered links. */
     a[x-apple-data-detectors],  /* iOS */
     .unstyle-auto-detected-links a,
     .aBn {
         border-bottom: 0 !important;
         cursor: default !important;
         color: inherit !important;
         text-decoration: none !important;
         font-size: inherit !important;
         font-family: inherit !important;
         font-weight: inherit !important;
         line-height: inherit !important;
     }

     /* What it does: Prevents Gmail from displaying a download button on large, non-linked images. */
     .a6S {
         display: none !important;
         opacity: 0.01 !important;
     }

     /* What it does: Prevents Gmail from changing the text color in conversation threads. */
     .im {
         color: inherit !important;
     }

     /* If the above doesn't work, add a .g-img class to any image in question. */
     img.g-img + div {
         display: none !important;
     }

     /* iPhone 4, 4S, 5, 5S, 5C, and 5SE */
     @media only screen and (min-device-width: 320px) and (max-device-width: 374px) {
         u ~ div .email-container {
             min-width: 320px !important;
         }

         .body-wrapper {
             padding: 1%;
         }

         .apple {
             margin: 10px 15px !important;
         }
     }
     /* iPhone 6, 6S, 7, 8, and X */
     @media only screen and (min-device-width: 375px) and (max-device-width: 413px) {
         u ~ div .email-container {
             min-width: 375px !important;
         }

         .body-wrapper {
             padding: 1%;
         }

         .apple {
             margin: 10px 25px !important;
         }
     }
     /* iPhone 6+, 7+, and 8+ */
     @media only screen and (min-device-width: 414px) {
         u ~ div .email-container {
             min-width: 414px !important;
         }

         .apple {
             margin: 10px 25px !important;
         }
     }

    </style>

    <!-- What it does: Makes background images in 72ppi Outlook render at correct size. -->
    <!--[if gte mso 9]>
      <xml>
      <o:OfficeDocumentSettings>
      <o:AllowPNG/>
      <o:PixelsPerInch>96</o:PixelsPerInch>
      </o:OfficeDocumentSettings>
      </xml>
    <![endif]-->

    <!-- Progressive Enhancements : BEGIN -->
    <style>

     /* Media Queries */
     @media screen and (max-width: 600px) {

         /* What it does: Adjust typography on small screens to improve readability */
         .email-container p {
             /*             font-size: 17px !important;*/
         }

     }

     /* custom css from here */

     body {
         font-family: "Open Sans", sans-serif;
     }

     .block_wrapper {
         border: 1px solid #d4d4d4;
         border-radius: 5px;
         margin: 10px 5% 10px;
         padding-bottom: 15px;
     }

     .store-logo {
         margin: 10px;
         display: inline-block;
     }

     .section-heading {
         color: #757575;
         font-size: 10px;
         padding: 5px;
     }

     .section-content {
         color: #424242;
         font-size: 14px;
         padding: 5px;
     }

     @media only screen and (width >= 768px) {

         .body-wrapper {
             padding: 6%;
         }

         .apple {
             margin: 10px 25px;
         }
     }


    </style>
    <!-- Progressive Enhancements : END -->

  </head>
  <!--
       The email background color (#222222) is defined in three places:
       1. body tag: for most email clients
       2. center tag: for Gmail and Inbox mobile apps and web versions of Gmail, GSuite, Inbox, Yahoo, AOL, Libero, Comcast, freenet, Mail.ru, Orange.fr
       3. mso conditional: For Windows 10 Mail
  -->
  <body width="100%" style="margin: 0; padding: 0 !important; mso-line-height-rule: exactly; background-color: #ffffff;">
    <center style="width: 100%; background-color: #ffffff;">
      <!--[if mso | IE]>
        <table role="presentation" border="0" cellpadding="0" cellspacing="0" width="100%" style="background-color: #ffffff;">
        <tr>
        <td>
      <![endif]-->

      <!--
           Set the email width. Defined in two places:
           1. max-width for all clients except Desktop Windows Outlook, allowing the email to squish on narrow but never go wider than 600px.
           2. MSO tags for Desktop Windows Outlook enforce a 600px width.
      -->
      <div style="max-width: 560px; min-width: 375px; margin: 0 auto; background-color: #F0F2F7;" class="email-container">
        <!--[if mso]>
          <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="600">
          <tr>
          <td>
        <![endif]-->

        <!-- Email Header : BEGIN -->

        <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
          <tr style="background-color: #151B42;">
            <td style="padding: 20px 0; text-align: center">
              <table role="presentation" cellspacing="0" cellpadding="0" width="100%">
                <tr>
                  <td>
                    <div style="padding: 20px;">
                      <a href="https://aviso.com" rel="noreferrer" target="_blank">
                        <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/aviso_red.png" />
                      </a>
                    </div>
                  </td>
                  <td style="color: #ffffff;width:60%;">
                    <span style="font-size: 20px !important; font-weight: bold; display: inline-block; margin-bottom: 5px; margin-left: 10px; vertical-align: bottom;position:relative;right:4px;">Discount Recommendation</span>
                    <span style="font-size: 20px !important; font-weight: bold; display: inline-block; margin-bottom: 5px; margin-left: 10px; vertical-align: bottom;font-weight:200;">{{date}}</span>
                  </td>
                </tr>
              </table>
            </td>
          </tr>
        </table>
        <!-- Email Header : END -->

        <!-- Email Body : BEGIN -->
        <div style="padding: 3% 2%;">
          <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
            <tbody style="background-color: #F0F2F7; border: 13px solid transparent;">
              <!-- Welcome user : BEGIN -->
              <tr>
                <td>
                  <div>
                    <h3 style="font-size: 20px;margin:0px;">Hi {{user_name}} <img src="https://aviso-email-images.s3.amazonaws.com/waving-hand_1f44b.png" style="position:relative;top:6px;height:27px;width:auto;">,</h3>
                    <p style="font-size: 16px;;margin-bottom:24px;color:black;font-weight:400;margin-top:8px;">A probable pipeline opportunity across accounts: </p>
                  </div>
                </td>
              </tr>

              <!-- Welcome user : END -->

              <!-- Content block : BEGIN -->

             </tr>




              <tr>
                <td>



                    <div style="width:512px;height:auto;background:white;">

                      <div style="color:#404255;font-size:16px;font-weight:bold;text-align:center;padding-top:24px;">
                        Discount Recommendation
                      </div>

                      <div style="background:#dff5ff;font-size:12px;font-weight:bold;text-align:center;font-weight:200;margin:auto;width:90%;padding:12px 8px;text-align:left;margin-top:16px;">
                        <p style="color:#6f7288;margin:0px;">Aviso recommends the following  discount percentages to be given to the products below to increase the chance of winning.
                      </div>

                {% for deal in deals[:3] %}
                   <div style="width:476px;height:auto;border-radius:5px;background:white;margin-top:24px;margin-bottom:5px;">
                    <img src="https://aviso-email-images.s3.amazonaws.com/win_scores/{{deal.aviso_score|int}}.png" style="display: inline-flex;
                                width: 32px;
                                height: 32px;
                                margin: 16px 18px;
                                vertical-align: top;
                                ">
                <div style="display:inline-block;min-width:40%;max-width:80%;margin-bottom:21.5px;">
                <div style="font-size:15px;margin-top:15px;margin-bottom:1px;font-weight:bold;word-break: normal;display:block; ">
               <div style="font-size:14px;font-weight: 600;">
              <a href="{{deal.update_deal_link}}" style="color:#0991cc;">{{deal.deal_name}}</a>
            </div>
            <div style="color:#6f7288;font-size:12px;font-weight:200;margin-top:0px;margin-bottom:3px;word-break: normal; ">
              Amount: <span style="font-weight:600;">{{deal.amount}}</span>
              <div style="width:3px;height:3px;border-radius:50%;display:inline-block;background:#6f7288;vertical-align:middle;margin-left:3px;margin-right:3px;"></div>
              Close Date: <span style="font-weight:600;">{{deal.close_date}}</span>
            </div>
                </div>
              </div>
              {% set rowloop = loop %}
              {% for key,value in deal.product_details.items() %}

              <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="table-layout:fixed;margin-left:15px !important;margin-right:15px !important;margin-top:13.5px !important;">
                <col width="30%">
                <col width="3%">
                <col width="40%">
                <col width="10%">
                <col width="4%">
                <col width="10%">


                <tr>
                  <td style="color:#0991cc;font-size:14px;font-weight:600;vertical-align:sub;">
                    {{key}}
                  </td>
                  <td style="vertical-align:sub;position:relative !important;bottom:2px !important;">
                    <div  style="width:3px;height:3px;border-radius:50%;background:#6f7288;margin-left:5px;margin-right:5px;">
                    </div>

                  </td>
                  <td style="font-size: 12px;font-weight: 600;color:#6f7288;vertical-align:sub;">
                    {{value.category_name}}

                  </td>
                  <td style="font-size: 14px;font-weight: 600;color:#404255;vertical-align:sub;">
                    {{value.unit_price}}

                  </td>
                  <td style="vertical-align:sub;position:relative !important;bottom:2px !important;">
                    <div style="width:7px;height:7px;border-radius:50%;background:#404255;margin-left:8px;margin-right:8px;">
                    </div>

                  </td>
                  <td style="font-size: 14px;font-weight: 600;color:#404255;text-align:right;vertical-align:sub;">
                    {{value.prod_disc|int}}%

                  </td>

                </tr>
                <tr>
                  <td colspan="6">
                  <div style="color:#6f7288;font-size:12px;font-weight:200;margin-top:0px;margin-bottom:11.5px;word-break: normal;display:flex;">
                    <img src="https://aviso-email-images.s3.amazonaws.com/lightbulb-on.png"style="width:16px;height:16px;padding-right:8px;"></img>
                    {% if value.prod_disc < 0 %}
                    A discount of {{value.category|int}}% is recommended based on the previous events
                    {%else %}
                    A raise of {{value.category|int}}% is recommended based on the previous events
                    {% endif %}
                     </div>
                  </td>

                </tr>

                {% if rowloop.index <= 3 and loop.index<= loop.length and not(rowloop.index ==3 and loop.last) %}
                <tr>
                  <td colspan="6">
                    <div style="border: 1px solid #acb0bd"></div>
                  </td>
                  <tr>

                    {%endif%}

              </table>
              {%endfor %}

            </div>

            {% endfor %}
            </div>

              </td>

              </tr>














                    <!-- <div style="width: 90%; border-bottom: 1px solid #757575; margin: 10px auto;"></div> -->
                    <!-- <div style="font-size: 14px; color: #404255; width: 84%; margin: 0 auto;">
                      <p style="color: #151B42;"><b>Deal Insights:</b></p>
                      <table role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
                        <tr>
                          <td style="width: 8%;">
                            <img src="https://aviso-email-images.s3.amazonaws.com/chevron-circle-up-solid 2.png" width="15.5px" height="15.5px" style="display: inline-block; margin-top: 2px;" />

                          </td>
                          <td>
                            <p style="margin-left: 5%;">This is an insight</p>
                              </td>
                            </tr>

                      </table>
                    </div> -->

              <!-- Content block : END -->
              <!-- Clear Spacer : BEGIN -->

              <!-- Clear Spacer : END -->

              <!-- 1 Column Text : BEGIN -->

              <tr>
                <td>
                  <p style="color: #404255; font-size: 14px; line-height: 20.9px; text-align: center; max-width: 360px;width:251px; margin: 0 auto;margin-top:40px;">Keep up-to-date with you deals on iPhone or Android with Aviso Go.</p>
                </td>
              </tr>
              <tr>
                <td style="background-color: #f0f2f7;">
                  <div style="max-width: 360px; margin: 0 auto;">
                    <a href="https://apps.apple.com/us/app/avisogo/id1250216779" style="margin: 0px 7%;">
                      <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/Apple-AppStore_download.png" style="40px;"/>
                    </a>
                    <a href="https://play.google.com/store/apps/details?id=com.aviso.avisogo"
                       style="margin: 10px;
                             display: inline-block;
                             ">
                      <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/Android-AppStore_download.png" />
                    </a>
                  </div>
                <a href="mailto:support@aviso.com?subject=Feedback%20on%20{{nudge_name}}"><p align="center" style="font-size:13px;color:#757575;font-weight:200;">Is this email useful?  We love <span style="color:#1f9ef4;"><u>feedback!</u></span></p><a/>

                </td>
              </tr>
              <!-- 1 Column Text : END -->
            </tbody>
          </table>
        </div>
        <!-- Email Body : END -->

        <!-- Email Footer : BEGIN -->
        <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%" style="margin: auto;">
          <tr>
            <td>
            <div style="width: 85%; border-bottom: 1px solid #c7cbd6; margin: 0 auto;"></div>
            </td>
          </tr>

          <tr>
            <td>
              <div style="width: 88%; margin: 0 auto;">
                <table role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%">
                  <tr>
                    <td style="width: 15%; padding: 5%;">
                      <img src="https://aviso-email-images.s3.amazonaws.com/aviso_logos/logo_footer_red.png" />
                    </td>
                    <td style="text-align:right;">
                        <p><a href="mailto:support@aviso.com?subject=Unscubscribe%20{{nudge_name}}" style="color: #757575; font-size: 10px;text-align:right;font-weight:200;"><u>Unscubscribe  from these emails</u></a></p>
                      <p style="color: #757575; font-size: 12px; line-height: 17.9px; text-align: right;">Copyright &copy; 2020 Aviso Inc. All rights reserved.</p>
                  </td>
                </tr>
              </table>
            </div>
          </td>
        </tr>
      </table>
      <!-- Email Footer : END -->

      <!--[if mso]>
        </td>
        </tr>
        </table>
      <![endif]-->
      </div>

      <!--[if mso | IE]>
        </td>
        </tr>
        </table>
      <![endif]-->
      <img src="{{opens_tracker}}" style="width: 1px; height: 1px">
    </center>
  </body>
</html>
"""
subject_template = '{{(tenant_name~" -- "~nudge_name~" - " if test_mode==True else "")~" '+ 'Discount recommendation for your deals from Aviso' +'"}}'
is_html = True
name = "discount_nudge"
optional = ["key","date"]

# %%
noti.api('/notify/api/email_template/', {"name": name,"subject_template":subject_template, "body_template": body_template,
                               "is_html": is_html, 'optional':optional, 'action': "update"} )
# Out:
# {u'message': u'Template added successfully', u'success': True}

# %%
noti.api('/notify/api/notification/', {'action':'create', 
                                       'name' : 'discount_nudge',
                                       'template_name':{'email':'discount_nudge'}, 
                                       'template_data':{
                                        "email": ['user_name', 'date', 'deals','key','nudge_name','tenant_name','test_mode','opens_tracker']
                                        },
                                         'track_urls':[]
                                      })
# Out:
# {u'action': u'create',
#  u'error': u'notification already created',
#  u'success': False}

# %%
event_name ='discount_nudge'

payload ={
    'test_mode':True,
    'tenant_name':"aditya",
    'nudge_name':"pace value Nudge",
    "user_name":"Final Nudge",
    "date":"6pm Jan 2020",
   'deals':[{
            "aviso_score":23,
            "update_deal_link":"www.abc.com",
            "deal_name":"Velo License nike-500 deals and changes.",
            "amount":"$23M",
            "close_date":"Jun 11,2020,6:05 PM",
            "product_details":{
                'Product1 the changes added to gold and ':{'prod':23,'disc':87,'unit_price':'$201','details':'sales','category_name':'retail management'},
                'Product2 which is the final change that is needed':{'prod':73,'disc':47,'unit_price':'$201','details':'retail','category_name':'Electronics'},
                
            }
            },{
            "aviso_score":23,
            "update_deal_link":"www.abc.com",
            "deal_name":"Velo License nike-500 deals and changes.",
            "amount":"$23M",
            "close_date":"Jun 11,2020,6:05 PM",
            "product_details":{
                'Product1':{'prod':23,'disc':87,'unit_price':'$201','details':'sales','category_name':'retail management'},
                'Product2':{'prod':73,'disc':47,'unit_price':'$201','details':'retail','category_name':'Electronics'},
                'Product3':{'prod':83,'disc':97,'unit_price':'$201','details':'Health','category_name':'Health'},
                'Product4':{'prod':89,'disc':96,'details':'manufactruing','unit_price':'$201','category_name':'Health'},
                'Product5':{'prod':23,'disc':87,'unit_price':'$201','details':'sales','category_name':'retail management'},
                'Product6':{'prod':73,'disc':47,'unit_price':'$201','details':'retail','category_name':'Electronics'},
                'Product7':{'prod':83,'disc':97,'unit_price':'$201','details':'Health','category_name':'Health'},
                'Product8':{'prod':89,'disc':96,'details':'manufactruing','unit_price':'$201','category_name':'Health'}
            }
            },{
            "aviso_score":23,
            "update_deal_link":"www.abc.com",
            "deal_name":"Velo License nike-500 deals and changes.",
            "amount":"$23M",
            "close_date":"Jun 11,2020,6:05 PM",
            "product_details":{
                'Product1 the changes added to gold and ':{'prod':23,'disc':87,'unit_price':'$201','details':'sales','category_name':'retail management'},
                'Product2 which is the final change that is needed':{'prod':73,'disc':47,'unit_price':'$201','details':'retail','category_name':'Electronics'},
                
            }
            },{
            "aviso_score":23,
            "update_deal_link":"www.abc.com",
            "deal_name":"Velo License nike-500 deals and changes.",
            "amount":"$23M",
            "close_date":"Jun 11,2020,6:05 PM",
            "product_details":{
                'Product1 the changes added to gold and ':{'prod':23,'disc':87,'unit_price':'$201','details':'sales','category_name':'retail management'},
                'Product2 which is the final change that is needed':{'prod':73,'disc':47,'unit_price':'$201','details':'retail','category_name':'Electronics'},
                
            }
            },{
            "aviso_score":23,
            "update_deal_link":"www.abc.com",
            "deal_name":"Velo License nike-500 deals and changes.",
            "amount":"$23M",
            "close_date":"Jun 11,2020,6:05 PM",
            "product_details":{
                'Product1 the changes added to gold and ':{'prod':23,'disc':87,'unit_price':'$201','details':'sales','category_name':'retail management'},
                'Product2 which is the final change that is needed':{'prod':73,'disc':47,'unit_price':'$201','details':'retail','category_name':'Electronics'},
                
            }
            },{
            "aviso_score":23,
            "update_deal_link":"www.abc.com",
            "deal_name":"Velo License nike-500 deals and changes.",
            "amount":"$23M",
            "close_date":"Jun 11,2020,6:05 PM",
            "product_details":{
                'Product1 the changes added to gold and ':{'prod_':23,'disc':87,'unit_price':'$201','details':'sales','category_name':'retail management'},
                'Product2 which is the final change that is needed':{'prod':73,'disc':47,'unit_price':'$201','details':'retail','category_name':'Electronics'},
                
            }
            }],
"opens_tracker":"abc.com",
"recipients": "aditya.lokesh@aviso.com",
"skip_header_footer": True,
    }
noti.api('/notify/api/test_notification', {'event_name': event_name, 'payload': payload})
# Out:
# {u'message': u'Event Published successfully', u'success': True}

# %%
event_name ='discount_nudge'
payload={
    'no_of_deals': 14,
    'event_trace': '3fb96729-be18-4a5c-b45b-26bb6ca0cad0',
    'test_mode': False, 
    'recipients': 'aditya.lokesh@aviso.com',
    'tenant_name': 'elastic_1',
    'filtered_deals': 'https://qa-ui-alpha.aviso.com/__track__...',
    'deals': [{'deal_owner': 'Thad Steele',
           'amount': '$1.2M',
           'update_deal_link': 'https://qa-ui-alpha.aviso.com/welcome/home/deals/2021Q4/2021Q4/revenue%2300Eb0000000HYcE/revenue%23005b0000003CFX2/grid-only/deal/0064M00000VylKl',
           'current_stage': '3 - Confirming Requirements and Budget', 
           'aviso_score': 51.0, 
           'deal_name': 'U.S. Bank National Association - Enterprise Agreement -  Observability',
           'product_details': {'Enterprise Resource Unit - 64GB': {'prod_disc': 39.54743986657038, 'category': -27.09243436828813, 'unit_price': 9000.0, 'category_name': 'On-Prem'}, 
                               'Private Training 10 (1-day)': {'prod_disc': -8.48528137423857, 'category': -14.422205101855956, 'unit_price': 9000.0, 'category_name': 'Training'},
                               'Embedded Architect 200': {'prod_disc': -18, 'category': -14.696938456699069, 'unit_price': 550000.0, 'category_name': 'Consulting'}, 
                               'Embedded Engineer 200': {'prod_disc': -13, 'category': -14.696938456699069, 'unit_price': 475000.0, 'category_name': 'Consulting'}},
           'raw_amount': 1228500}, 
          {'deal_owner': 'Thad Steele',
           'amount': '$463.7K', 
           'update_deal_link': 'https://qa-ui-alpha.aviso.com/welcome/home/deals/2021Q4/2021Q4/revenue%2300Eb0000000HYcE/revenue%23005b0000003CFX2/grid-only/deal/0064M00000XdRHB',
           'current_stage': '6 - Finalizing PO and Order Form',
           'aviso_score': 91.0, 
           'deal_name': 'United HealthCare Services, Inc. - Renewal -  Enterprise Search - Renewal',
           'product_details': {'Custom Platinum Subscription per node - 128GB': {'prod_disc': 52.009614495783374, 'category': -27.09243436828813, 'unit_price': 2970.0, 'category_name': 'On-Prem'}, 
                               'Platinum Subscription per node - 128GB': {'prod_disc': -21.6794833886788, 'category': -27.09243436828813, 'unit_price': 2318.58, 'category_name': 'On-Prem'}}, 
           'raw_amount': 463716}, 
          {'deal_owner': 'Thad Steele',
           'amount': '$168.5K', 
           'update_deal_link': 'https://qa-ui-alpha.aviso.com/welcome/home/deals/2021Q4/2021Q4/revenue%2300Eb0000000HYcE/revenue%23005b0000003CFX2/grid-only/deal/0064M00000XdghL', 
           'current_stage': '3 - Confirming Requirements and Budget',
           'aviso_score': 65.0,
           'deal_name': 'Unitedhealth Group Incorporated - Online Training Subscription - 10 - Elastic fo', 
           'product_details': {'Professional Annual Training Subscription': {'prod_disc': 11.090536506409418, 'category': -14.422205101855956, 'unit_price': 5615.34, 'category_name': 'Training'},
                              'Professional Annual Training Subscription': {'prod_disc': -11.090536506409418, 'category': -14.422205101855956, 'unit_price': 5615.34, 'category_name': 'Training'},
                              'Nike licenses velo 500': {'prod_disc': -12.090536506409418, 'category': -16.422205101855956, 'unit_price': 5125.34, 'category_name': 'Training'}},
           'raw_amount': 168460}], 'email': 'aditya.lokesh@aviso.com', 
        'view_all_deals': 'https://qa-ui-alpha.aviso.com/__track__...', 
            'skip_header_footer': True,
            'nudge_name': 'DISCOUNT NUDGE',
            'user_name': 'Pavan Mithinti', 
            'uuid': '04f110a4-06a6-413a-b90a-59536f6e369f', 
            'opens_tracker': 'https://notification-qa.aviso.com/notify/track_opens?user_id=f468169ac7ee52029c9ca4e8b4c66a77&tenant=elastic_1.com&notification_type=discount_nudge&channel=mobile&uuid=04f110a4-06a6-413a-b90a-59536f6e369f'}
noti.api('/notify/api/test_notification', {'event_name': event_name, 'payload': payload})
# Out:
# {u'message': u'Event Published successfully', u'success': True}
